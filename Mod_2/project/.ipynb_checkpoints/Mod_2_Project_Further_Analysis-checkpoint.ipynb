# %%
import numpy as np
import pandas as pd 

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical Analysis
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

import pickle

# %%
df = pd.read_csv('df_ms.csv')
pd.set_option('display.max_rows', None) #In order to view all rows
pd.set_option('display.max_columns', None) #In order to view all columns
df = df.drop('Unnamed: 0',axis=1) #Removing weird column
df
# Out:
#     fips_code state                    name  poor_or_fair_health  \
# 0       28000    MS             Mississippi             0.222107
# 1       28001    MS            Adams County             0.252348
# 2       28003    MS           Alcorn County             0.206829
# 3       28005    MS            Amite County             0.233394
# 4       28007    MS           Attala County             0.223945
# 5       28009    MS           Benton County             0.226610
# 6       28011    MS          Bolivar County             0.288365
# 7       28013    MS          Calhoun County             0.250819
# 8       28015    MS          Carroll County             0.189839
# 9       28017    MS        Chickasaw County             0.261095
# 10      28019    MS          Choctaw County             0.229651
# 11      28021    MS        Claiborne County             0.349595
# 12      28023    MS           Clarke County             0.190027
# 13      28025    MS             Clay County             0.244244
# 14      28027    MS          Coahoma County             0.290499
# 15      28029    MS           Copiah County             0.249389
# 16      28031    MS        Covington County             0.244406
# 17      28033    MS           DeSoto County             0.164740
# 18      28035    MS          Forrest County             0.201349
# 19      28037    MS         Franklin County             0.207107
# 20      28039    MS           George County             0.168255
# 21      28041    MS           Greene County             0.167598
# 22      28043    MS          Grenada County             0.222589
# 23      28045    MS          Hancock County             0.174155
# 24      28047    MS         Harrison County             0.213562
# 25      28049    MS            Hinds County             0.220743
# 26      28051    MS           Holmes County             0.350827
# 27      28053    MS        Humphreys County             0.360108
# 28      28055    MS        Issaquena County             0.320184
# 29      28057    MS         Itawamba County             0.190532
# 30      28059    MS          Jackson County             0.172725
# 31      28061    MS           Jasper County             0.233485
# 32      28063    MS        Jefferson County             0.345652
# 33      28065    MS  Jefferson Davis County             0.296384
# 34      28067    MS            Jones County             0.225664
# 35      28069    MS           Kemper County             0.278196
# 36      28071    MS        Lafayette County             0.191062
# 37      28073    MS            Lamar County             0.180088
# 38      28075    MS       Lauderdale County             0.229170
# 39      28077    MS         Lawrence County             0.214418
# 40      28079    MS            Leake County             0.251148
# 41      28081    MS              Lee County             0.189556
# 42      28083    MS          Leflore County             0.311513
# 43      28085    MS          Lincoln County             0.211865
# 44      28087    MS          Lowndes County             0.212255
# 45      28089    MS          Madison County             0.159165
# 46      28091    MS           Marion County             0.237626
# 47      28093    MS         Marshall County             0.207517
# 48      28095    MS           Monroe County             0.199850
# 49      28097    MS       Montgomery County             0.246176
# 50      28099    MS          Neshoba County             0.248430
# 51      28101    MS           Newton County             0.200758
# 52      28103    MS          Noxubee County             0.265153
# 53      28105    MS        Oktibbeha County             0.223236
# 54      28107    MS           Panola County             0.239813
# 55      28109    MS      Pearl River County             0.186917
# 56      28111    MS            Perry County             0.216035
# 57      28113    MS             Pike County             0.243002
# 58      28115    MS         Pontotoc County             0.195779
# 59      28117    MS         Prentiss County             0.234886
# 60      28119    MS          Quitman County             0.346461
# 61      28121    MS           Rankin County             0.146538
# 62      28123    MS            Scott County             0.260185
# 63      28125    MS          Sharkey County             0.303631
# %%
df.describe()
# Out:
#           fips_code  poor_or_fair_health  monthly_poor_physical_health_days  \
# count     83.000000            83.000000                          83.000000
# mean   28081.012048             0.235075                           4.325070
# std       48.187260             0.047284                           0.477247
# min    28000.000000             0.146538                           3.316584
# 25%    28040.000000             0.201543                           4.031532
# 50%    28081.000000             0.226610                           4.271664
# 75%    28122.000000             0.260640                           4.605437
# max    28163.000000             0.360108                           5.622736
#
#        monthly_poor_mental_health_days  adult_smoking  adult_obesity  \
# count                        83.000000      83.000000      83.000000
# mean                          4.262161       0.207271       0.379530
# std                           0.294330       0.024227       0.035235
# min                           3.392336       0.150740       0.306000
# 25%                           4.074021       0.190828       0.357000
# 50%                           4.279764       0.203010       0.373000
# 75%                           4.418529       0.218187       0.402000
# max                           5.122680       0.271309       0.495000
#
#        physical_inactivity  access_to_exercise  excessive_drinking  \
# count            83.000000           83.000000           83.000000
# mean              0.328723            0.429003            0.127037
# std               0.032471            0.225734            0.018352
# min               0.236000            0.000000            0.094077
# 25%               0.313500            0.271715            0.114666
# 50%               0.329000            0.430928            0.125201
# 75%               0.348500            0.612525            0.136678
# max               0.398000            0.881189            0.171469
#
#        alcohol_impaired_driving_deaths  uninsured_under_65  \
# count                        83.000000           83.000000
# mean                          0.214142            0.150256
# std                           0.129431            0.019111
# min                           0.000000            0.095436
# 25%                           0.134848            0.139049
# 50%                           0.200000            0.149954
# 75%                           0.283817            0.158866
# max                           0.826087            0.194828
#
#        primary_care_physicians   dentists  mental_health_providers  \
# count                83.000000  83.000000                83.000000
# mean                  0.000405   0.000339                 0.001045
# std                   0.000253   0.000180                 0.001205
# min                   0.000000   0.000000                 0.000069
# 25%                   0.000217   0.000222                 0.000224
# 50%                   0.000378   0.000307                 0.000512
# 75%                   0.000520   0.000409                 0.001517
# max                   0.001412   0.001026                 0.005517
#
#        flu_vaccinations  high_school_grad  some_college  unemployed  \
# count         83.000000         83.000000     83.000000   83.000000
# mean           0.362892          0.829540      0.525864    0.059753
# std            0.092163          0.046589      0.100729    0.018041
# min            0.150000          0.720000      0.260504    0.035662
# 25%            0.290000          0.803695      0.451449    0.048336
# 50%            0.370000          0.828031      0.532346    0.055311
# 75%            0.430000          0.875000      0.581700    0.067571
# max            0.530000          0.925000      0.778522    0.147157
#
#        children_in_poverty  single_parent_households  social_associations  \
# count            83.000000                 83.000000            83.000000
# mean              0.325578                  0.462316            12.910761
# std               0.103992                  0.130458             3.586878
# min               0.119000                  0.228222             2.740852
# 25%               0.246500                  0.347443            10.245351
# 50%               0.316000                  0.445263            12.762789
# 75%               0.377500                  0.560506            14.902867
# max               0.602000                  0.777663            23.130301
#
#        violent_crime  injury_deaths  severe_housing_problems  \
# count      83.000000      83.000000                83.000000
# mean       97.867442      93.486570                 0.160293
# std       159.511203      22.091984                 0.034425
# min         0.000000      25.590719                 0.097264
# 25%         0.000000      79.425702                 0.136052
# 50%         0.000000      93.192222                 0.157921
# 75%       167.986339     105.802076                 0.179833
# max       755.012751     161.695393                 0.251992
#
#        households_with_high_housing_costs  households_with_overcrowding  \
# count                           83.000000                     83.000000
# mean                             0.130315                      0.030124
# std                              0.035207                      0.012320
# min                              0.074336                      0.009869
# 25%                              0.103811                      0.022045
# 50%                              0.127179                      0.027027
# 75%                              0.148818                      0.035401
# max                              0.224199                      0.081454
#
#        households_with_lack_of_kitchen_or_plumbing_facilities  \
# count                                          83.000000
# mean                                            0.010842
# std                                             0.006897
# min                                             0.000984
# 25%                                             0.006107
# 50%                                             0.009195
# 75%                                             0.013869
# max                                             0.040021
#
#        life_expectancy  diabetes_prevalence  hiv_prevalence  \
# count        83.000000            83.000000       83.000000
# mean         74.087409             0.151096      296.243373
# std           1.893595             0.018715      201.701840
# min          70.155742             0.101000       10.400000
# 25%          72.624202             0.141500      172.700000
# 50%          74.120591             0.150000      257.100000
# 75%          75.235287             0.163500      386.100000
# max          78.974871             0.198000     1175.300000
#
#        limited_access_to_healthy_foods  drug_overdose_deaths  \
# count                        83.000000             83.000000
# mean                          0.108352              7.285663
# std                           0.073720              6.870100
# min                           0.000000              3.212149
# 25%                           0.058579              3.212149
# 50%                           0.088806              3.212149
# 75%                           0.140801             10.670969
# max                           0.325064             32.575058
#
#        motor_vehicle_crash_deaths  uninsured_adults  uninsured_children  \
# count                   83.000000         83.000000           83.000000
# mean                    29.439438          0.191554            0.050407
# std                     10.285407          0.024730            0.008016
# min                      2.806817          0.117309            0.034087
# 25%                     22.908193          0.178775            0.045412
# 50%                     28.448014          0.190511            0.049626
# 75%                     37.066382          0.204190            0.055880
# max                     58.250046          0.251864            0.069196
#
#        other_primary_care_providers  median_household_income  \
# count                     83.000000                83.000000
# mean                       0.000804             38726.060241
# std                        0.000438              8649.330991
# min                        0.000000             24783.000000
# 25%                        0.000529             32788.000000
# 50%                        0.000748             38385.000000
# 75%                        0.000994             43027.500000
# max                        0.002438             69820.000000
#
#        children_eligible_for_free_or_reduced_price_lunch  homicides  \
# count                                          83.000000  83.000000
# mean                                            0.815362   9.350602
# std                                             0.151563   8.066392
# min                                             0.466016   0.700000
# 25%                                             0.707598   0.700000
# 50%                                             0.805451   7.900000
# 75%                                             0.992458  14.700000
# max                                             1.000000  34.600000
#
#        firearm_fatalities  homeownership  severe_housing_cost_burden  \
# count           83.000000      83.000000                   83.000000
# mean            17.566265       0.707702                    0.131993
# std              9.206139       0.099372                    0.037420
# min              1.700000       0.375094                    0.067763
# 25%             14.150000       0.655668                    0.105293
# 50%             17.700000       0.725946                    0.128691
# 75%             22.550000       0.765487                    0.156461
# max             44.700000       0.894460                    0.220724
#
#          population  proficient_in_English
# count  8.300000e+01              83.000000
# mean   7.190602e+04               0.006237
# std    3.264059e+05               0.009484
# min    1.339000e+03               0.000000
# 25%    1.299400e+04               0.001167
# 50%    2.315400e+04               0.003684
# 75%    3.654100e+04               0.007948
# max    2.984100e+06               0.066914

# %%
df.life_expectancy.sort_values()
# Out:
# 50    70.155742
# 72    70.815008
# 60    70.881287
# 79    70.915209
# 14    71.321585
# 26    71.488448
# 67    71.519012
# 42    71.535933
# 63    71.761942
# 76    71.793772
# 6     71.874095
# 4     71.916088
# 5     71.978073
# 20    72.046644
# 32    72.103395
# 57    72.235237
# 46    72.249405
# 12    72.333353
# 39    72.494352
# 71    72.612493
# 11    72.624196
# 70    72.624207
# 54    72.674030
# 16    72.684384
# 22    72.758046
# 82    72.789913
# 33    72.911447
# 75    73.090604
# 81    73.169995
# 43    73.177234
# 2     73.324604
# 51    73.508473
# 62    73.546519
# 52    73.654068
# 78    73.690212
# 49    73.731423
# 21    73.748371
# 15    73.884214
# 66    73.986043
# 47    74.054254
# 59    74.092928
# 27    74.120591
# 55    74.350233
# 34    74.355641
# 7     74.385560
# 18    74.414171
# 64    74.441927
# 1     74.451844
# 68    74.452503
# 80    74.631435
# 41    74.670495
# 9     74.767725
# 29    74.781666
# 0     74.810028
# 13    74.857743
# 69    74.927388
# 10    74.986425
# 77    75.081441
# 24    75.092930
# 19    75.173351
# 38    75.176077
# 31    75.180656
# 25    75.289918
# 48    75.294282
# 56    75.294729
# 44    75.418808
# 74    75.489282
# 40    75.625910
# 65    75.898747
# 23    76.017284
# 35    76.021235
# 73    76.066787
# 58    76.228844
# 30    76.318980
# 3     76.330296
# 45    76.624179
# 17    76.908781
# 36    77.211155
# 28    77.464748
# 53    77.775624
# 37    77.941106
# 8     78.193303
# 61    78.974871
# Name: life_expectancy, dtype: float64

# %%
df_ms_1 = df.loc[(df['fips_code'] == 28099)] 
df_ms_2 = df.loc[(df['fips_code'] == 28143)] 
df_ms_3 = df.loc[(df['fips_code'] == 28119)] 
#Accessing the 3 counties with the lowest life expectancy

# %%
df_ms_1
# Out:
#     fips_code state            name  poor_or_fair_health  \
# 50      28099    MS  Neshoba County              0.24843
#
#     monthly_poor_physical_health_days  monthly_poor_mental_health_days  \
# 50                           4.699476                         4.649394
#
#     adult_smoking  adult_obesity  physical_inactivity  access_to_exercise  \
# 50       0.216942          0.394                0.331            0.451409
#
#     excessive_drinking  alcohol_impaired_driving_deaths  uninsured_under_65  \
# 50            0.128953                              0.2            0.173226
#
#     primary_care_physicians  dentists  mental_health_providers  \
# 50                 0.000578  0.000579                 0.000715
#
#     flu_vaccinations  high_school_grad  some_college  unemployed  \
# 50              0.23          0.803865      0.524791    0.050775
#
#     children_in_poverty  single_parent_households  social_associations  \
# 50                 0.31                   0.52412            13.604054
#
#     violent_crime  injury_deaths  severe_housing_problems  \
# 50            0.0      116.84227                 0.158287
#
#     households_with_high_housing_costs  households_with_overcrowding  \
# 50                            0.107143                      0.052607
#
#     households_with_lack_of_kitchen_or_plumbing_facilities  life_expectancy  \
# 50                                           0.007914             70.155742
#
#     diabetes_prevalence  hiv_prevalence  limited_access_to_healthy_foods  \
# 50                0.143           196.4                         0.037923
#
#     drug_overdose_deaths  motor_vehicle_crash_deaths  uninsured_adults  \
# 50             13.600045                   37.715778          0.233105
#
#     uninsured_children  other_primary_care_providers  median_household_income  \
# 50            0.056103                       0.00109                  38728.0
#
#     children_eligible_for_free_or_reduced_price_lunch  homicides  \
# 50                                           0.746117       10.6
#
#     firearm_fatalities  homeownership  severe_housing_cost_burden  population  \
# 50                27.2       0.734893                    0.109977     29369.0
#
#     proficient_in_English
# 50               0.007923

# %%
df_ms_2
# Out:
#     fips_code state           name  poor_or_fair_health  \
# 72      28143    MS  Tunica County             0.272366
#
#     monthly_poor_physical_health_days  monthly_poor_mental_health_days  \
# 72                           4.603902                         4.263273
#
#     adult_smoking  adult_obesity  physical_inactivity  access_to_exercise  \
# 72       0.222389          0.407                0.331            0.562071
#
#     excessive_drinking  alcohol_impaired_driving_deaths  uninsured_under_65  \
# 72            0.114528                         0.307692            0.115224
#
#     primary_care_physicians  dentists  mental_health_providers  \
# 72                 0.000098  0.000457                 0.000299
#
#     flu_vaccinations  high_school_grad  some_college  unemployed  \
# 72              0.36             0.875      0.585142    0.058081
#
#     children_in_poverty  single_parent_households  social_associations  \
# 72                0.446                  0.715124              7.81708
#
#     violent_crime  injury_deaths  severe_housing_problems  \
# 72     429.205247      73.417183                 0.249373
#
#     households_with_high_housing_costs  households_with_overcrowding  \
# 72                             0.17762                      0.081454
#
#     households_with_lack_of_kitchen_or_plumbing_facilities  life_expectancy  \
# 72                                           0.008772             70.815008
#
#     diabetes_prevalence  hiv_prevalence  limited_access_to_healthy_foods  \
# 72                0.147           805.7                         0.096319
#
#     drug_overdose_deaths  motor_vehicle_crash_deaths  uninsured_adults  \
# 72              3.212149                   17.841948          0.155619
#
#     uninsured_children  other_primary_care_providers  median_household_income  \
# 72            0.034087                      0.000599                  31492.0
#
#     children_eligible_for_free_or_reduced_price_lunch  homicides  \
# 72                                                1.0       19.2
#
#     firearm_fatalities  homeownership  severe_housing_cost_burden  population  \
# 72                 1.7       0.375094                    0.212385     10024.0
#
#     proficient_in_English
# 72               0.009949

# %%
df_ms_3
# Out:
#     fips_code state            name  poor_or_fair_health  \
# 60      28119    MS  Quitman County             0.346461
#
#     monthly_poor_physical_health_days  monthly_poor_mental_health_days  \
# 60                           5.375611                         4.824687
#
#     adult_smoking  adult_obesity  physical_inactivity  access_to_exercise  \
# 60       0.260783          0.411                0.382            0.173781
#
#     excessive_drinking  alcohol_impaired_driving_deaths  uninsured_under_65  \
# 60             0.09568                         0.307692            0.164686
#
#     primary_care_physicians  dentists  mental_health_providers  \
# 60                 0.000136  0.000138                 0.000413
#
#     flu_vaccinations  high_school_grad  some_college  unemployed  \
# 60              0.38             0.825      0.401705    0.087324
#
#     children_in_poverty  single_parent_households  social_associations  \
# 60                0.575                  0.623789            12.246564
#
#     violent_crime  injury_deaths  severe_housing_problems  \
# 60            0.0     133.031795                 0.181669
#
#     households_with_high_housing_costs  households_with_overcrowding  \
# 60                            0.158249                       0.03437
#
#     households_with_lack_of_kitchen_or_plumbing_facilities  life_expectancy  \
# 60                                           0.004583             70.881287
#
#     diabetes_prevalence  hiv_prevalence  limited_access_to_healthy_foods  \
# 60                0.163           466.3                         0.236305
#
#     drug_overdose_deaths  motor_vehicle_crash_deaths  uninsured_adults  \
# 60              3.212149                   41.108433          0.214771
#
#     uninsured_children  other_primary_care_providers  median_household_income  \
# 60             0.04185                      0.000825                  26740.0
#
#     children_eligible_for_free_or_reduced_price_lunch  homicides  \
# 60                                                1.0       18.7
#
#     firearm_fatalities  homeownership  severe_housing_cost_burden  population  \
# 60                 1.7       0.655273                    0.165693      7269.0
#
#     proficient_in_English
# 60               0.007944

# %%
df_ms_l3c = pd.concat([df_ms_1, df_ms_2, df_ms_3], ignore_index=True)
df_ms_l3c
# Out:
#    fips_code state            name  poor_or_fair_health  \
# 0      28099    MS  Neshoba County             0.248430
# 1      28143    MS   Tunica County             0.272366
# 2      28119    MS  Quitman County             0.346461
#
#    monthly_poor_physical_health_days  monthly_poor_mental_health_days  \
# 0                           4.699476                         4.649394
# 1                           4.603902                         4.263273
# 2                           5.375611                         4.824687
#
#    adult_smoking  adult_obesity  physical_inactivity  access_to_exercise  \
# 0       0.216942          0.394                0.331            0.451409
# 1       0.222389          0.407                0.331            0.562071
# 2       0.260783          0.411                0.382            0.173781
#
#    excessive_drinking  alcohol_impaired_driving_deaths  uninsured_under_65  \
# 0            0.128953                         0.200000            0.173226
# 1            0.114528                         0.307692            0.115224
# 2            0.095680                         0.307692            0.164686
#
#    primary_care_physicians  dentists  mental_health_providers  \
# 0                 0.000578  0.000579                 0.000715
# 1                 0.000098  0.000457                 0.000299
# 2                 0.000136  0.000138                 0.000413
#
#    flu_vaccinations  high_school_grad  some_college  unemployed  \
# 0              0.23          0.803865      0.524791    0.050775
# 1              0.36          0.875000      0.585142    0.058081
# 2              0.38          0.825000      0.401705    0.087324
#
#    children_in_poverty  single_parent_households  social_associations  \
# 0                0.310                  0.524120            13.604054
# 1                0.446                  0.715124             7.817080
# 2                0.575                  0.623789            12.246564
#
#    violent_crime  injury_deaths  severe_housing_problems  \
# 0       0.000000     116.842270                 0.158287
# 1     429.205247      73.417183                 0.249373
# 2       0.000000     133.031795                 0.181669
#
#    households_with_high_housing_costs  households_with_overcrowding  \
# 0                            0.107143                      0.052607
# 1                            0.177620                      0.081454
# 2                            0.158249                      0.034370
#
#    households_with_lack_of_kitchen_or_plumbing_facilities  life_expectancy  \
# 0                                           0.007914             70.155742
# 1                                           0.008772             70.815008
# 2                                           0.004583             70.881287
#
#    diabetes_prevalence  hiv_prevalence  limited_access_to_healthy_foods  \
# 0                0.143           196.4                         0.037923
# 1                0.147           805.7                         0.096319
# 2                0.163           466.3                         0.236305
#
#    drug_overdose_deaths  motor_vehicle_crash_deaths  uninsured_adults  \
# 0             13.600045                   37.715778          0.233105
# 1              3.212149                   17.841948          0.155619
# 2              3.212149                   41.108433          0.214771
#
#    uninsured_children  other_primary_care_providers  median_household_income  \
# 0            0.056103                      0.001090                  38728.0
# 1            0.034087                      0.000599                  31492.0
# 2            0.041850                      0.000825                  26740.0
#
#    children_eligible_for_free_or_reduced_price_lunch  homicides  \
# 0                                           0.746117       10.6
# 1                                           1.000000       19.2
# 2                                           1.000000       18.7
#
#    firearm_fatalities  homeownership  severe_housing_cost_burden  population  \
# 0                27.2       0.734893                    0.109977     29369.0
# 1                 1.7       0.375094                    0.212385     10024.0
# 2                 1.7       0.655273                    0.165693      7269.0
#
#    proficient_in_English
# 0               0.007923
# 1               0.009949
# 2               0.007944

# %%
df_ms_l3c.describe()
# Out:
#           fips_code  poor_or_fair_health  monthly_poor_physical_health_days  \
# count      3.000000             3.000000                           3.000000
# mean   28120.333333             0.289086                           4.892996
# std       22.030282             0.051110                           0.420679
# min    28099.000000             0.248430                           4.603902
# 25%    28109.000000             0.260398                           4.651689
# 50%    28119.000000             0.272366                           4.699476
# 75%    28131.000000             0.309414                           5.037543
# max    28143.000000             0.346461                           5.375611
#
#        monthly_poor_mental_health_days  adult_smoking  adult_obesity  \
# count                         3.000000       3.000000       3.000000
# mean                          4.579118       0.233371       0.404000
# std                           0.287229       0.023895       0.008888
# min                           4.263273       0.216942       0.394000
# 25%                           4.456333       0.219665       0.400500
# 50%                           4.649394       0.222389       0.407000
# 75%                           4.737040       0.241586       0.409000
# max                           4.824687       0.260783       0.411000
#
#        physical_inactivity  access_to_exercise  excessive_drinking  \
# count             3.000000            3.000000            3.000000
# mean              0.348000            0.395753            0.113054
# std               0.029445            0.200039            0.016685
# min               0.331000            0.173781            0.095680
# 25%               0.331000            0.312595            0.105104
# 50%               0.331000            0.451409            0.114528
# 75%               0.356500            0.506740            0.121741
# max               0.382000            0.562071            0.128953
#
#        alcohol_impaired_driving_deaths  uninsured_under_65  \
# count                         3.000000            3.000000
# mean                          0.271795            0.151045
# std                           0.062176            0.031315
# min                           0.200000            0.115224
# 25%                           0.253846            0.139955
# 50%                           0.307692            0.164686
# 75%                           0.307692            0.168956
# max                           0.307692            0.173226
#
#        primary_care_physicians  dentists  mental_health_providers  \
# count                 3.000000  3.000000                 3.000000
# mean                  0.000271  0.000391                 0.000476
# std                   0.000267  0.000228                 0.000215
# min                   0.000098  0.000138                 0.000299
# 25%                   0.000117  0.000297                 0.000356
# 50%                   0.000136  0.000457                 0.000413
# 75%                   0.000357  0.000518                 0.000564
# max                   0.000578  0.000579                 0.000715
#
#        flu_vaccinations  high_school_grad  some_college  unemployed  \
# count          3.000000          3.000000      3.000000    3.000000
# mean           0.323333          0.834622      0.503879    0.065394
# std            0.081445          0.036530      0.093490    0.019340
# min            0.230000          0.803865      0.401705    0.050775
# 25%            0.295000          0.814433      0.463248    0.054428
# 50%            0.360000          0.825000      0.524791    0.058081
# 75%            0.370000          0.850000      0.554967    0.072703
# max            0.380000          0.875000      0.585142    0.087324
#
#        children_in_poverty  single_parent_households  social_associations  \
# count             3.000000                  3.000000             3.000000
# mean              0.443667                  0.621011            11.222566
# std               0.132515                  0.095532             3.026334
# min               0.310000                  0.524120             7.817080
# 25%               0.378000                  0.573954            10.031822
# 50%               0.446000                  0.623789            12.246564
# 75%               0.510500                  0.669456            12.925309
# max               0.575000                  0.715124            13.604054
#
#        violent_crime  injury_deaths  severe_housing_problems  \
# count       3.000000       3.000000                 3.000000
# mean      143.068416     107.763749                 0.196443
# std       247.801765      30.826776                 0.047306
# min         0.000000      73.417183                 0.158287
# 25%         0.000000      95.129727                 0.169978
# 50%         0.000000     116.842270                 0.181669
# 75%       214.602623     124.937032                 0.215521
# max       429.205247     133.031795                 0.249373
#
#        households_with_high_housing_costs  households_with_overcrowding  \
# count                            3.000000                      3.000000
# mean                             0.147671                      0.056144
# std                              0.036410                      0.023740
# min                              0.107143                      0.034370
# 25%                              0.132696                      0.043488
# 50%                              0.158249                      0.052607
# 75%                              0.167935                      0.067030
# max                              0.177620                      0.081454
#
#        households_with_lack_of_kitchen_or_plumbing_facilities  \
# count                                           3.000000
# mean                                            0.007090
# std                                             0.002213
# min                                             0.004583
# 25%                                             0.006248
# 50%                                             0.007914
# 75%                                             0.008343
# max                                             0.008772
#
#        life_expectancy  diabetes_prevalence  hiv_prevalence  \
# count         3.000000             3.000000        3.000000
# mean         70.617346             0.151000      489.466667
# std           0.401132             0.010583      305.309914
# min          70.155742             0.143000      196.400000
# 25%          70.485375             0.145000      331.350000
# 50%          70.815008             0.147000      466.300000
# 75%          70.848148             0.155000      636.000000
# max          70.881287             0.163000      805.700000
#
#        limited_access_to_healthy_foods  drug_overdose_deaths  \
# count                         3.000000              3.000000
# mean                          0.123516              6.674781
# std                           0.101949              5.997455
# min                           0.037923              3.212149
# 25%                           0.067121              3.212149
# 50%                           0.096319              3.212149
# 75%                           0.166312              8.406097
# max                           0.236305             13.600045
#
#        motor_vehicle_crash_deaths  uninsured_adults  uninsured_children  \
# count                    3.000000          3.000000            3.000000
# mean                    32.222053          0.201165            0.044013
# std                     12.568536          0.040495            0.011166
# min                     17.841948          0.155619            0.034087
# 25%                     27.778863          0.185195            0.037969
# 50%                     37.715778          0.214771            0.041850
# 75%                     39.412105          0.223938            0.048977
# max                     41.108433          0.233105            0.056103
#
#        other_primary_care_providers  median_household_income  \
# count                      3.000000                 3.000000
# mean                       0.000838             32320.000000
# std                        0.000246              6036.739517
# min                        0.000599             26740.000000
# 25%                        0.000712             29116.000000
# 50%                        0.000825             31492.000000
# 75%                        0.000958             35110.000000
# max                        0.001090             38728.000000
#
#        children_eligible_for_free_or_reduced_price_lunch  homicides  \
# count                                           3.000000   3.000000
# mean                                            0.915372  16.166667
# std                                             0.146579   4.827353
# min                                             0.746117  10.600000
# 25%                                             0.873059  14.650000
# 50%                                             1.000000  18.700000
# 75%                                             1.000000  18.950000
# max                                             1.000000  19.200000
#
#        firearm_fatalities  homeownership  severe_housing_cost_burden  \
# count            3.000000       3.000000                    3.000000
# mean            10.200000       0.588420                    0.162685
# std             14.722432       0.188986                    0.051270
# min              1.700000       0.375094                    0.109977
# 25%              1.700000       0.515184                    0.137835
# 50%              1.700000       0.655273                    0.165693
# 75%             14.450000       0.695083                    0.189039
# max             27.200000       0.734893                    0.212385
#
#          population  proficient_in_English
# count      3.000000               3.000000
# mean   15554.000000               0.008605
# std    12043.179605               0.001163
# min     7269.000000               0.007923
# 25%     8646.500000               0.007934
# 50%    10024.000000               0.007944
# 75%    19696.500000               0.008947
# max    29369.000000               0.009949

# %%
sns.regplot(x='median_household_income', y='life_expectancy', data=df)

# %%
sns.kdeplot(df.median_household_income, df.life_expectancy)

# %%
sns.regplot(x='adult_obesity', y='life_expectancy', data=df)

# %%
sns.kdeplot(df.adult_obesity, df.life_expectancy)

# %%
sns.regplot(x='diabetes_prevalence', y='life_expectancy', data=df)

# %%
sns.kdeplot(df.diabetes_prevalence, df.life_expectancy)

# %%
sns.regplot(x='physical_inactivity', y='life_expectancy', data=df)

# %%
sns.kdeplot(df.physical_inactivity, df.life_expectancy)

# %%
sns.regplot(x='adult_smoking', y='life_expectancy', data=df)

# %%
sns.kdeplot(df.adult_smoking, df.life_expectancy)

# %%
sns.regplot(x='single_parent_households', y='life_expectancy', data=df)

# %%
sns.kdeplot(df.single_parent_households, df.life_expectancy)

# %%
health_features = ['adult_smoking', 'adult_obesity', 'physical_inactivity',
            'excessive_drinking', 'uninsured_under_65',
            'primary_care_physicians', 'dentists', 'mental_health_providers', 'flu_vaccinations', 
            'unemployed', 'diabetes_prevalence', 'hiv_prevalence', 
            'limited_access_to_healthy_foods', 
            'uninsured_adults', 'uninsured_children', 'other_primary_care_providers',
            'median_household_income']
df_health_features = df[health_features]

social_features = ['poor_or_fair_health', 
            'monthly_poor_physical_health_days', 'monthly_poor_mental_health_days', 
            'access_to_exercise',
            'alcohol_impaired_driving_deaths', 
            'high_school_grad', 'some_college', 'unemployed', 'children_in_poverty', 
            'single_parent_households', 'social_associations', 'violent_crime', 'injury_deaths', 
            'severe_housing_problems', 'households_with_high_housing_costs', 
            'households_with_overcrowding', 'households_with_lack_of_kitchen_or_plumbing_facilities',
            'drug_overdose_deaths', 'motor_vehicle_crash_deaths', 
            'median_household_income', 'children_eligible_for_free_or_reduced_price_lunch',
            'homicides', 'firearm_fatalities', 'homeownership', 'severe_housing_cost_burden', 
            'population', 'proficient_in_English']
df_social_features = df[social_features]

target = df['life_expectancy']

# %%
#Distribute columns into groups of 4 per row
n = 4
row_groups = [health_features[i:i+n] for i in range(0, len(health_features), n)]
for i in row_groups:
    pp = sns.pairplot(data=df, y_vars=['life_expectancy'],x_vars=i, kind="reg", height=3)

# %%
#Distribute columns into groups of 4 per row
n = 4
row_groups = [social_features[i:i+n] for i in range(0, len(social_features), n)]
for i in row_groups:
    pp = sns.pairplot(data=df, y_vars=['life_expectancy'],x_vars=i, kind="reg", height=3)

# %%
import warnings
warnings.filterwarnings('ignore')
fig = plt.figure(figsize = (20,20))
ax = fig.gca()
df.hist(ax = ax);

# %%
mlr_model = ols(formula='life_expectancy~poor_or_fair_health+monthly_poor_physical_health_days+monthly_poor_mental_health_days+adult_smoking+adult_obesity+physical_inactivity+access_to_exercise+excessive_drinking+alcohol_impaired_driving_deaths+uninsured_under_65+primary_care_physicians+dentists+mental_health_providers+flu_vaccinations+high_school_grad+some_college+unemployed+children_in_poverty+single_parent_households+social_associations+violent_crime+injury_deaths+severe_housing_problems+households_with_high_housing_costs+households_with_overcrowding+households_with_lack_of_kitchen_or_plumbing_facilities+diabetes_prevalence+hiv_prevalence+limited_access_to_healthy_foods+drug_overdose_deaths+motor_vehicle_crash_deaths+uninsured_adults+uninsured_children+other_primary_care_providers+median_household_income+children_eligible_for_free_or_reduced_price_lunch+homicides+firearm_fatalities+homeownership+severe_housing_cost_burden+population+proficient_in_English', data=df).fit()
mlr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0
# motor_vehicle_crash_deaths                                -0.0118      0.038     -0.313      0.756      -0.088       0.064
# uninsured_adults                                        -158.7659     51.687     -3.072      0.004    -263.230     -54.302
# uninsured_children                                       -86.5544     57.291     -1.511      0.139    -202.343      29.234
# other_primary_care_providers                             320.6966    547.648      0.586      0.561    -786.142    1427.535
# median_household_income                                 6.003e-05   5.22e-05      1.149      0.257   -4.55e-05       0.000
# children_eligible_for_free_or_reduced_price_lunch          0.3336      2.321      0.144      0.886      -4.357       5.024
# homicides                                                  0.0233      0.040      0.579      0.566      -0.058       0.105
# firearm_fatalities                                        -0.0177      0.031     -0.577      0.567      -0.080       0.044
# homeownership                                              3.9578      3.687      1.073      0.290      -3.494      11.409
# severe_housing_cost_burden                                16.9929     12.009      1.415      0.165      -7.277      41.263
# population                                                6.8e-07   5.41e-07      1.257      0.216   -4.14e-07    1.77e-06
# proficient_in_English                                     35.8381     20.801      1.723      0.093      -6.202      77.879
# ==============================================================================
# Omnibus:                        3.660   Durbin-Watson:                   2.136
# Prob(Omnibus):                  0.160   Jarque-Bera (JB):                3.197
# Skew:                           0.272   Prob(JB):                        0.202
# Kurtosis:                       3.793   Cond. No.                     5.24e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.24e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
corr_health = df_health_features.corr()
corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col1 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col2 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col4 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col5 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col6 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col7 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col8 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col9 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col10 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col11 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col12 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col13 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col14 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col15 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col0 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col2 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col3 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col4 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col5 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col6 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col7 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col8 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col9 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col10 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col11 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col12 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col13 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col14 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col15 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row1_col16 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col0 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col1 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col3 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col4 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col5 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col6 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col7 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col8 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col9 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col10 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col11 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col12 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col13 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col14 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col15 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row2_col16 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row3_col2 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row3_col4 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row3_col5 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row3_col6 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row3_col7 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_f7a00136_b2eb_11ea_9b12_3e22fb6f73f8row3_col8 {
#             background-color:  #f6bfa6;

# %%
corr_social = df_social_features.corr()
corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col1 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col2 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col4 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col5 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col6 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col7 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col8 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col9 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col10 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col11 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col12 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col13 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col14 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col15 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col0 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col2 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col3 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col4 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col5 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col6 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col7 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col8 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col9 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col10 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col11 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col12 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col13 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col14 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col15 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row1_col16 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col0 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col1 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col3 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col4 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col5 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col6 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col7 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col8 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col9 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col10 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col11 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col12 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col13 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col14 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col15 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row2_col16 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row3_col2 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row3_col4 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row3_col5 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row3_col6 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row3_col7 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_fe209c0a_b2eb_11ea_9b12_3e22fb6f73f8row3_col8 {
#             background-color:  #f6bfa6;

# %%
mlr_model_2 = ols(formula='life_expectancy~adult_smoking+adult_obesity+physical_inactivity+excessive_drinking+primary_care_physicians+dentists+mental_health_providers+flu_vaccinations+unemployed+diabetes_prevalence+hiv_prevalence+limited_access_to_healthy_foods+uninsured_adults+uninsured_children+other_primary_care_providers+median_household_income', data=df).fit()
mlr_model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     4.450
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           7.52e-06
# Time:                        07:52:37   Log-Likelihood:                -139.89
# No. Observations:                  83   AIC:                             313.8
# Df Residuals:                      66   BIC:                             354.9
# Df Model:                          16
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          65.5916      6.693      9.799      0.000      52.228      78.956
# adult_smoking                       2.1326     13.296      0.160      0.873     -24.413      28.678
# adult_obesity                       2.8570      8.551      0.334      0.739     -14.217      19.931
# physical_inactivity               -12.0876      7.288     -1.659      0.102     -26.638       2.463
# excessive_drinking                 15.1211     19.639      0.770      0.444     -24.089      54.331
# primary_care_physicians          -807.4798   1077.045     -0.750      0.456   -2957.870    1342.910
# dentists                         1215.3468   1654.938      0.734      0.465   -2088.843    4519.537
# mental_health_providers           218.5882    175.266      1.247      0.217    -131.342     568.518
# flu_vaccinations                    1.4128      2.332      0.606      0.547      -3.243       6.069
# unemployed                          8.1508     15.584      0.523      0.603     -22.964      39.266
# diabetes_prevalence                 5.8458     14.806      0.395      0.694     -23.714      35.406
# hiv_prevalence                     -0.0013      0.001     -1.186      0.240      -0.004       0.001
# limited_access_to_healthy_foods     3.9029      2.866      1.362      0.178      -1.819       9.625
# uninsured_adults                   -2.7962     14.330     -0.195      0.846     -31.406      25.814
# uninsured_children                 72.8385     41.162      1.770      0.081      -9.344     155.021
# other_primary_care_providers     -522.8604    521.395     -1.003      0.320   -1563.858     518.138
# median_household_income             0.0001   4.45e-05      2.363      0.021    1.63e-05       0.000
# ==============================================================================
# Omnibus:                        1.036   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.596   Jarque-Bera (JB):                0.626
# Skew:                          -0.198   Prob(JB):                        0.731
# Kurtosis:                       3.158   Cond. No.                     4.40e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.4e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
def CorrMtx(df, dropDuplicates = True):

    # Your dataset is already a correlation matrix.
    # If you have a dateset where you need to include the calculation
    # of a correlation matrix, just uncomment the line below:
    # df = df.corr()

    # Exclude duplicate correlations by masking uper right values
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True

    # Set background color / chart style
    sns.set_style(style = 'white')

    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))

    # Add diverging colormap from red to blue
    cmap = sns.diverging_palette(250, 10, as_cmap=True)

    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        sns.heatmap(df, mask=mask, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)


CorrMtx(corr_health, dropDuplicates = True)

# %%
def CorrMtx(df, dropDuplicates = True):

    # Your dataset is already a correlation matrix.
    # If you have a dateset where you need to include the calculation
    # of a correlation matrix, just uncomment the line below:
    # df = df.corr()

    # Exclude duplicate correlations by masking uper right values
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True

    # Set background color / chart style
    sns.set_style(style = 'white')

    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))

    # Add diverging colormap from red to blue
    cmap = sns.diverging_palette(250, 10, as_cmap=True)

    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        sns.heatmap(df, mask=mask, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)


CorrMtx(corr_social, dropDuplicates = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_health_features, target, random_state=25,test_size=0.2)

# %%
scaler = StandardScaler()

# fit the scaler to the training data
scaler.fit(X_train)

#transform the training data
X_train = pd.DataFrame(data=scaler.transform(X_train), columns=df_health_features.columns)

#transform the testing dat
X_test = pd.DataFrame(data=scaler.transform(X_test), columns=df_health_features.columns)

# %%
#instantiate a linear regression object
lm = LinearRegression()

#fit the linear regression to the data
lm = lm.fit(X_train, y_train)

y_train_pred = lm.predict(X_train)

train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))


print('Training Root Mean Squared Error:' , train_rmse)
# Out:
# Training Root Mean Squared Error: 1.0865347265364171

# %%
#use fitted model to predict on the test examples
y_pred = lm.predict(X_test)

#evaluate the predictions on the test examples
test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Testing Root Mean Squared Error:' , test_rmse)


print('Training: ', int(train_rmse), "vs. Testing: ", int(test_rmse))
# Out:
# Testing Root Mean Squared Error: 1.1595110130914483
# Training:  1 vs. Testing:  1

# %%
sns.residplot( y_train, y_train_pred,lowess=True, color="r")

# %%
sns.residplot( y_test, y_pred, lowess=True, color="b")

# %%
y_log = np.sqrt(y_train)

# %%
#instantiate a linear regression object
lm_log = LinearRegression()

#fit the linear regression to the data
lm_log = lm_log.fit(X_train, y_log)

y_train_pred = lm_log.predict(X_train)

#exponentiate the predictions to get them on the same original scale 
y_train_pred = np.square(y_train_pred)

train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))


print('Training Root Mean Squared Error:' , train_rmse)
# Out:
# Training Root Mean Squared Error: 1.0862495100295781

# %%
y_test_pred = lm_log.predict(X_test)


#our model predcicte the log of gross, so now we must exponentiate to get the value in $
y_test_pred = np.square(y_test_pred)

test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))

print('Testing Root Mean Squared Error:' , test_rmse)


print('Training: ', int(train_rmse), "vs. Testing: ", int(test_rmse))
# Out:
# Testing Root Mean Squared Error: 1.1572966653109409
# Training:  1 vs. Testing:  1

# %%
sns.residplot( y_test, y_test_pred, lowess=True, color="g")

# %%
poly_2 = PolynomialFeatures(degree=2, include_bias=False)
poly2_data = poly_2.fit_transform(df_health_features)
poly2_columns = poly_2.get_feature_names(df_health_features.columns)
df_poly2 = pd.DataFrame(poly2_data, columns=poly2_columns)
df_poly2.head()
# Out:
#    adult_smoking  adult_obesity  physical_inactivity  excessive_drinking  \
# 0       0.227407          0.365                0.313            0.136770
# 1       0.228640          0.378                0.309            0.125201
# 2       0.191566          0.360                0.348            0.135918
# 3       0.206888          0.413                0.341            0.113224
# 4       0.187388          0.395                0.336            0.121838
#
#    uninsured_under_65  primary_care_physicians  dentists  \
# 0            0.139798                 0.000528  0.000467
# 1            0.140841                 0.000832  0.000452
# 2            0.141820                 0.000295  0.000484
# 3            0.172025                 0.000161  0.000241
# 4            0.138016                 0.000475  0.000325
#
#    mental_health_providers  flu_vaccinations  unemployed  diabetes_prevalence  \
# 0                 0.001425              0.39    0.050746                0.141
# 1                 0.000710              0.44    0.072914                0.145
# 2                 0.002741              0.42    0.043989                0.137
# 3                 0.000080              0.20    0.066534                0.163
# 4                 0.000271              0.47    0.061401                0.170
#
#    hiv_prevalence  limited_access_to_healthy_foods  uninsured_adults  \
# 0           374.0                         0.106594          0.178396
# 1           384.4                         0.133368          0.178952
# 2           125.5                         0.046792          0.179983
# 3           187.6                         0.089350          0.210159
# 4           205.7                         0.115136          0.180006
#
#    uninsured_children  other_primary_care_providers  median_household_income  \
# 0            0.046922                      0.001016                  43595.0
# 1            0.042348                      0.001097                  31044.0
# 2            0.048239                      0.001397                  39528.0
# 3            0.069196                      0.000562                  35422.0
# 4            0.046773                      0.000595                  35158.0
#
#    adult_smoking^2  adult_smoking adult_obesity  \
# 0         0.051714                     0.083003
# 1         0.052276                     0.086426
# 2         0.036697                     0.068964
# 3         0.042802                     0.085445
# 4         0.035114                     0.074018
#
#    adult_smoking physical_inactivity  adult_smoking excessive_drinking  \
# 0                           0.071178                          0.031102
# 1                           0.070650                          0.028626
# 2                           0.066665                          0.026037
# 3                           0.070549                          0.023425
# 4                           0.062962                          0.022831
#
#    adult_smoking uninsured_under_65  adult_smoking primary_care_physicians  \
# 0                          0.031791                               0.000120
# 1                          0.032202                               0.000190
# 2                          0.027168                               0.000056
# 3                          0.035590                               0.000033
# 4                          0.025863                               0.000089
#
#    adult_smoking dentists  adult_smoking mental_health_providers  \
# 0                0.000106                               0.000324
# 1                0.000103                               0.000162
# 2                0.000093                               0.000525
# 3                0.000050                               0.000017
# 4                0.000061                               0.000051
#
#    adult_smoking flu_vaccinations  adult_smoking unemployed  \
# 0                        0.088689                  0.011540
# 1                        0.100602                  0.016671
# 2                        0.080458                  0.008427
# 3                        0.041378                  0.013765
# 4                        0.088072                  0.011506
#
#    adult_smoking diabetes_prevalence  adult_smoking hiv_prevalence  \
# 0                           0.032064                     85.050036
# 1                           0.033153                     87.889327
# 2                           0.026245                     24.041501
# 3                           0.033723                     38.812096
# 4                           0.031856                     38.545673
#
#    adult_smoking limited_access_to_healthy_foods  \
# 0                                       0.024240
# 1                                       0.030493
# 2                                       0.008964
# 3                                       0.018485
# 4                                       0.021575
#
#    adult_smoking uninsured_adults  adult_smoking uninsured_children  \
# 0                        0.040568                          0.010670
# 1                        0.040916                          0.009682
# 2                        0.034479                          0.009241
# 3                        0.043479                          0.014316
# 4                        0.033731                          0.008765
#
#    adult_smoking other_primary_care_providers  \
# 0                                    0.000231
# 1                                    0.000251
# 2                                    0.000268
# 3                                    0.000116
# 4                                    0.000112
#
#    adult_smoking median_household_income  adult_obesity^2  \
# 0                            9913.786926         0.133225
# 1                            7097.909085         0.142884
# 2                            7572.210824         0.129600
# 3                            7328.369305         0.170569
# 4                            6588.180645         0.156025
#
#    adult_obesity physical_inactivity  adult_obesity excessive_drinking  \
# 0                           0.114245                          0.049921
# 1                           0.116802                          0.047326
# 2                           0.125280                          0.048931
# 3                           0.140833                          0.046761
# 4                           0.132720                          0.048126
#
#    adult_obesity uninsured_under_65  adult_obesity primary_care_physicians  \
# 0                          0.051026                               0.000193
# 1                          0.053238                               0.000315
# 2                          0.051055                               0.000106
# 3                          0.071046                               0.000066
# 4                          0.054516                               0.000188
#
#    adult_obesity dentists  adult_obesity mental_health_providers  \
# 0                0.000171                               0.000520
# 1                0.000171                               0.000268
# 2                0.000174                               0.000987
# 3                0.000100                               0.000033
# 4                0.000128                               0.000107
#
#    adult_obesity flu_vaccinations  adult_obesity unemployed  \
# 0                         0.14235                  0.018522
# 1                         0.16632                  0.027561
# 2                         0.15120                  0.015836
# 3                         0.08260                  0.027478
# 4                         0.18565                  0.024253
#
#    adult_obesity diabetes_prevalence  adult_obesity hiv_prevalence  \
# 0                           0.051465                      136.5100
# 1                           0.054810                      145.3032
# 2                           0.049320                       45.1800
# 3                           0.067319                       77.4788
# 4                           0.067150                       81.2515
#
#    adult_obesity limited_access_to_healthy_foods  \
# 0                                       0.038907
# 1                                       0.050413
# 2                                       0.016845
# 3                                       0.036901
# 4                                       0.045479
#
#    adult_obesity uninsured_adults  adult_obesity uninsured_children  \
# 0                        0.065114                          0.017127
# 1                        0.067644                          0.016007
# 2                        0.064794                          0.017366
# 3                        0.086796                          0.028578
# 4                        0.071102                          0.018475
#
#    adult_obesity other_primary_care_providers  \
# 0                                    0.000371
# 1                                    0.000415
# 2                                    0.000503
# 3                                    0.000232
# 4                                    0.000235
#
#    adult_obesity median_household_income  physical_inactivity^2  \
# 0                              15912.175               0.097969
# 1                              11734.632               0.095481
# 2                              14230.080               0.121104
# 3                              14629.286               0.116281
# 4                              13887.410               0.112896
#
#    physical_inactivity excessive_drinking  \
# 0                                0.042809
# 1                                0.038687
# 2                                0.047300
# 3                                0.038609
# 4                                0.040938
#
#    physical_inactivity uninsured_under_65  \
# 0                                0.043757
# 1                                0.043520
# 2                                0.049353
# 3                                0.058661
# 4                                0.046373
#
#    physical_inactivity primary_care_physicians  physical_inactivity dentists  \
# 0                                     0.000165                      0.000146
# 1                                     0.000257                      0.000140
# 2                                     0.000103                      0.000168
# 3                                     0.000055                      0.000082
# 4                                     0.000160                      0.000109
#
#    physical_inactivity mental_health_providers  \
# 0                                     0.000446
# 1                                     0.000219
# 2                                     0.000954
# 3                                     0.000027
# 4                                     0.000091
#
#    physical_inactivity flu_vaccinations  physical_inactivity unemployed  \
# 0                               0.12207                        0.015884
# 1                               0.13596                        0.022530
# 2                               0.14616                        0.015308
# 3                               0.06820                        0.022688
# 4                               0.15792                        0.020631
#
#    physical_inactivity diabetes_prevalence  \
# 0                                 0.044133
# 1                                 0.044805
# 2                                 0.047676
# 3                                 0.055583
# 4                                 0.057120
#
#    physical_inactivity hiv_prevalence  \
# 0                            117.0620
# 1                            118.7796
# 2                             43.6740
# 3                             63.9716
# 4                             69.1152
#
#    physical_inactivity limited_access_to_healthy_foods  \
# 0                                           0.033364
# 1                                           0.041211
# 2                                           0.016283
# 3                                           0.030468
# 4                                           0.038686
#
#    physical_inactivity uninsured_adults  \
# 0                              0.055838
# 1                              0.055296
# 2                              0.062634
# 3                              0.071664
# 4                              0.060482
#
#    physical_inactivity uninsured_children  \
# 0                                0.014687
# 1                                0.013085
# 2                                0.016787
# 3                                0.023596
# 4                                0.015716
#
#    physical_inactivity other_primary_care_providers  \
# 0                                          0.000318
# 1                                          0.000339
# 2                                          0.000486
# 3                                          0.000192
# 4                                          0.000200
#
#    physical_inactivity median_household_income  excessive_drinking^2  \
# 0                                    13645.235              0.018706
# 1                                     9592.596              0.015675
# 2                                    13755.744              0.018474
# 3                                    12078.902              0.012820
# 4                                    11813.088              0.014845
#
#    excessive_drinking uninsured_under_65  \
# 0                               0.019120
# 1                               0.017634
# 2                               0.019276
# 3                               0.019477
# 4                               0.016816
#
#    excessive_drinking primary_care_physicians  excessive_drinking dentists  \
# 0                                    0.000072                     0.000064
# 1                                    0.000104                     0.000057
# 2                                    0.000040                     0.000066
# 3                                    0.000018                     0.000027
# 4                                    0.000058                     0.000040
#
#    excessive_drinking mental_health_providers  \
# 0                                    0.000195
# 1                                    0.000089
# 2                                    0.000373
# 3                                    0.000009
# 4                                    0.000033
#
#    excessive_drinking flu_vaccinations  excessive_drinking unemployed  \
# 0                             0.053340                       0.006941
# 1                             0.055088                       0.009129
# 2                             0.057086                       0.005979
# 3                             0.022645                       0.007533
# 4                             0.057264                       0.007481
#
#    excessive_drinking diabetes_prevalence  excessive_drinking hiv_prevalence  \
# 0                                0.019285                          51.152148
# 1                                0.018154                          48.127307
# 2                                0.018621                          17.057724
# 3                                0.018455                          21.240757
# 4                                0.020712                          25.062123
#
#    excessive_drinking limited_access_to_healthy_foods  \
# 0                                           0.014579
# 1                                           0.016698
# 2                                           0.006360
# 3                                           0.010116
# 4                                           0.014028
#
#    excessive_drinking uninsured_adults  excessive_drinking uninsured_children  \
# 0                             0.024399                               0.006418
# 1                             0.022405                               0.005302
# 2                             0.024463                               0.006557
# 3                             0.023795                               0.007835
# 4                             0.021932                               0.005699
#
#    excessive_drinking other_primary_care_providers  \
# 0                                         0.000139
# 1                                         0.000137
# 2                                         0.000190
# 3                                         0.000064
# 4                                         0.000073
#
#    excessive_drinking median_household_income  uninsured_under_65^2  \
# 0                                 5962.507737              0.019544
# 1                                 3886.743290              0.019836
# 2                                 5372.571479              0.020113
# 3                                 4010.608116              0.029593
# 4                                 4283.588371              0.019048
#
#    uninsured_under_65 primary_care_physicians  uninsured_under_65 dentists  \
# 0                                    0.000074                     0.000065
# 1                                    0.000117                     0.000064
# 2                                    0.000042                     0.000069
# 3                                    0.000028                     0.000041
# 4                                    0.000066                     0.000045
#
#    uninsured_under_65 mental_health_providers  \
# 0                                    0.000199
# 1                                    0.000100
# 2                                    0.000389
# 3                                    0.000014
# 4                                    0.000037
#
#    uninsured_under_65 flu_vaccinations  uninsured_under_65 unemployed  \
# 0                             0.054521                       0.007094
# 1                             0.061970                       0.010269
# 2                             0.059564                       0.006238
# 3                             0.034405                       0.011445
# 4                             0.064868                       0.008474
#
#    uninsured_under_65 diabetes_prevalence  uninsured_under_65 hiv_prevalence  \
# 0                                0.019712                          52.284564
# 1                                0.020422                          54.139448
# 2                                0.019429                          17.798409
# 3                                0.028040                          32.271900
# 4                                0.023463                          28.389921
#
#    uninsured_under_65 limited_access_to_healthy_foods  \
# 0                                           0.014902
# 1                                           0.018784
# 2                                           0.006636
# 3                                           0.015370
# 4                                           0.015891
#
#    uninsured_under_65 uninsured_adults  uninsured_under_65 uninsured_children  \
# 0                             0.024939                               0.006560
# 1                             0.025204                               0.005964
# 2                             0.025525                               0.006841
# 3                             0.036153                               0.011904
# 4                             0.024844                               0.006455
#
#    uninsured_under_65 other_primary_care_providers  \
# 0                                         0.000142
# 1                                         0.000154
# 2                                         0.000198
# 3                                         0.000097
# 4                                         0.000082
#
#    uninsured_under_65 median_household_income  primary_care_physicians^2  \
# 0                                 6094.506871               2.784141e-07
# 1                                 4372.281511               6.923127e-07
# 2                                 5605.860569               8.695097e-08
# 3                                 6093.471399               2.577290e-08
# 4                                 4852.371556               2.259437e-07
#
#    primary_care_physicians dentists  \
# 0                      2.466644e-07
# 1                      3.757296e-07
# 2                      1.426429e-07
# 3                      3.869351e-08
# 4                      1.543547e-07
#
#    primary_care_physicians mental_health_providers  \
# 0                                     7.516633e-07
# 1                                     5.904323e-07
# 2                                     8.083096e-07
# 3                                     1.289783e-08
# 4                                     1.286289e-07
#
#    primary_care_physicians flu_vaccinations  \
# 0                                  0.000206
# 1                                  0.000366
# 2                                  0.000124
# 3                                  0.000032
# 4                                  0.000223
#
#    primary_care_physicians unemployed  \
# 0                            0.000027
# 1                            0.000061
# 2                            0.000013
# 3                            0.000011
# 4                            0.000029
#
#    primary_care_physicians diabetes_prevalence  \
# 0                                     0.000074
# 1                                     0.000121
# 2                                     0.000040
# 3                                     0.000026
# 4                                     0.000081
#
#    primary_care_physicians hiv_prevalence  \
# 0                                0.197341
# 1                                0.319841
# 2                                0.037007
# 3                                0.030117
# 4                                0.097776
#
#    primary_care_physicians limited_access_to_healthy_foods  \
# 0                                           0.000056
# 1                                           0.000111
# 2                                           0.000014
# 3                                           0.000014
# 4                                           0.000055
#
#    primary_care_physicians uninsured_adults  \
# 0                                  0.000094
# 1                                  0.000149
# 2                                  0.000053
# 3                                  0.000034
# 4                                  0.000086
#
#    primary_care_physicians uninsured_children  \
# 0                                    0.000025
# 1                                    0.000035
# 2                                    0.000014
# 3                                    0.000011
# 4                                    0.000022
#
#    primary_care_physicians other_primary_care_providers  \
# 0                                       5.359425e-07
# 1                                       9.124863e-07
# 2                                       4.120794e-07
# 3                                       9.028487e-08
# 4                                       2.829837e-07
#
#    primary_care_physicians median_household_income    dentists^2  \
# 0                                        23.002884  2.185353e-07
# 1                                        25.830263  2.039147e-07
# 2                                        11.655799  2.340053e-07
# 3                                         5.686627  5.809156e-08
# 4                                        16.711842  1.054483e-07
#
#    dentists mental_health_providers  dentists flu_vaccinations  \
# 0                      6.659453e-07                   0.000182
# 1                      3.204374e-07                   0.000199
# 2                      1.326030e-06                   0.000203
# 3                      1.936384e-08                   0.000048
# 4                      8.787357e-08                   0.000153
#
#    dentists unemployed  dentists diabetes_prevalence  dentists hiv_prevalence  \
# 0             0.000024                      0.000066                 0.174837
# 1             0.000033                      0.000065                 0.173583
# 2             0.000021                      0.000066                 0.060709
# 3             0.000016                      0.000039                 0.045216
# 4             0.000020                      0.000055                 0.066797
#
#    dentists limited_access_to_healthy_foods  dentists uninsured_adults  \
# 0                                  0.000050                   0.000083
# 1                                  0.000060                   0.000081
# 2                                  0.000023                   0.000087
# 3                                  0.000022                   0.000051
# 4                                  0.000037                   0.000058
#
#    dentists uninsured_children  dentists other_primary_care_providers  \
# 0                     0.000022                           4.748248e-07
# 1                     0.000019                           4.952215e-07
# 2                     0.000023                           6.760152e-07
# 3                     0.000017                           1.355470e-07
# 4                     0.000015                           1.933218e-07
#
#    dentists median_household_income  mental_health_providers^2  \
# 0                         20.379686               2.029343e-06
# 1                         14.018514               5.035445e-07
# 2                         19.121310               7.514170e-06
# 3                          8.537478               6.454612e-09
# 4                         11.416787               7.322799e-08
#
#    mental_health_providers flu_vaccinations  \
# 0                                  0.000556
# 1                                  0.000312
# 2                                  0.001151
# 3                                  0.000016
# 4                                  0.000127
#
#    mental_health_providers unemployed  \
# 0                            0.000072
# 1                            0.000052
# 2                            0.000121
# 3                            0.000005
# 4                            0.000017
#
#    mental_health_providers diabetes_prevalence  \
# 0                                     0.000201
# 1                                     0.000103
# 2                                     0.000376
# 3                                     0.000013
# 4                                     0.000046
#
#    mental_health_providers hiv_prevalence  \
# 0                                0.532782
# 1                                0.272774
# 2                                0.344020
# 3                                0.015072
# 4                                0.055664
#
#    mental_health_providers limited_access_to_healthy_foods  \
# 0                                           0.000152
# 1                                           0.000095
# 2                                           0.000128
# 3                                           0.000007
# 4                                           0.000031
#
#    mental_health_providers uninsured_adults  \
# 0                                  0.000254
# 1                                  0.000127
# 2                                  0.000493
# 3                                  0.000017
# 4                                  0.000049
#
#    mental_health_providers uninsured_children  \
# 0                                    0.000067
# 1                                    0.000030
# 2                                    0.000132
# 3                                    0.000006
# 4                                    0.000013
#
#    mental_health_providers other_primary_care_providers  \
# 0                                       1.446939e-06
# 1                                       7.782052e-07
# 2                                       3.830753e-06
# 3                                       4.518231e-08
# 4                                       1.611016e-07
#
#    mental_health_providers median_household_income  flu_vaccinations^2  \
# 0                                        62.103262              0.1521
# 1                                        22.029092              0.1936
# 2                                       108.354098              0.1764
# 3                                         2.845825              0.0400
# 4                                         9.513990              0.2209
#
#    flu_vaccinations unemployed  flu_vaccinations diabetes_prevalence  \
# 0                     0.019791                               0.05499
# 1                     0.032082                               0.06380
# 2                     0.018475                               0.05754
# 3                     0.013307                               0.03260
# 4                     0.028858                               0.07990
#
#    flu_vaccinations hiv_prevalence  \
# 0                          145.860
# 1                          169.136
# 2                           52.710
# 3                           37.520
# 4                           96.679
#
#    flu_vaccinations limited_access_to_healthy_foods  \
# 0                                          0.041572
# 1                                          0.058682
# 2                                          0.019652
# 3                                          0.017870
# 4                                          0.054114
#
#    flu_vaccinations uninsured_adults  flu_vaccinations uninsured_children  \
# 0                           0.069574                             0.018300
# 1                           0.078739                             0.018633
# 2                           0.075593                             0.020261
# 3                           0.042032                             0.013839
# 4                           0.084603                             0.021983
#
#    flu_vaccinations other_primary_care_providers  \
# 0                                       0.000396
# 1                                       0.000483
# 2                                       0.000587
# 3                                       0.000112
# 4                                       0.000280
#
#    flu_vaccinations median_household_income  unemployed^2  \
# 0                                  17002.05      0.002575
# 1                                  13659.36      0.005316
# 2                                  16601.76      0.001935
# 3                                   7084.40      0.004427
# 4                                  16524.26      0.003770
#
#    unemployed diabetes_prevalence  unemployed hiv_prevalence  \
# 0                        0.007155                  18.979007
# 1                        0.010573                  28.028095
# 2                        0.006026                   5.520596
# 3                        0.010845                  12.481703
# 4                        0.010438                  12.630182
#
#    unemployed limited_access_to_healthy_foods  unemployed uninsured_adults  \
# 0                                    0.005409                     0.009053
# 1                                    0.009724                     0.013048
# 2                                    0.002058                     0.007917
# 3                                    0.005945                     0.013983
# 4                                    0.007069                     0.011053
#
#    unemployed uninsured_children  unemployed other_primary_care_providers  \
# 0                       0.002381                                 0.000052
# 1                       0.003088                                 0.000080
# 2                       0.002122                                 0.000061
# 3                       0.004604                                 0.000037
# 4                       0.002872                                 0.000037
#
#    unemployed median_household_income  diabetes_prevalence^2  \
# 0                         2212.272197               0.019881
# 1                         2263.538419               0.021025
# 2                         1738.789935               0.018769
# 3                         2356.753161               0.026569
# 4                         2158.735658               0.028900
#
#    diabetes_prevalence hiv_prevalence  \
# 0                             52.7340
# 1                             55.7380
# 2                             17.1935
# 3                             30.5788
# 4                             34.9690
#
#    diabetes_prevalence limited_access_to_healthy_foods  \
# 0                                           0.015030
# 1                                           0.019338
# 2                                           0.006410
# 3                                           0.014564
# 4                                           0.019573
#
#    diabetes_prevalence uninsured_adults  \
# 0                              0.025154
# 1                              0.025948
# 2                              0.024658
# 3                              0.034256
# 4                              0.030601
#
#    diabetes_prevalence uninsured_children  \
# 0                                0.006616
# 1                                0.006140
# 2                                0.006609
# 3                                0.011279
# 4                                0.007951
#
#    diabetes_prevalence other_primary_care_providers  \
# 0                                          0.000143
# 1                                          0.000159
# 2                                          0.000191
# 3                                          0.000092
# 4                                          0.000101
#
#    diabetes_prevalence median_household_income  hiv_prevalence^2  \
# 0                                     6146.895         139876.00
# 1                                     4501.380         147763.36
# 2                                     5415.336          15750.25
# 3                                     5773.786          35193.76
# 4                                     5976.860          42312.49
#
#    hiv_prevalence limited_access_to_healthy_foods  \
# 0                                       39.866178
# 1                                       51.266579
# 2                                        5.872338
# 3                                       16.761986
# 4                                       23.683418
#
#    hiv_prevalence uninsured_adults  hiv_prevalence uninsured_children  \
# 0                        66.719936                          17.548904
# 1                        68.789287                          16.278455
# 2                        22.587909                           6.054035
# 3                        39.425896                          12.981250
# 4                        37.027194                           9.621181
#
#    hiv_prevalence other_primary_care_providers  \
# 0                                     0.379878
# 1                                     0.421559
# 2                                     0.175383
# 3                                     0.105503
# 4                                     0.122460
#
#    hiv_prevalence median_household_income  limited_access_to_healthy_foods^2  \
# 0                              16304530.0                           0.011362
# 1                              11933313.6                           0.017787
# 2                               4960764.0                           0.002189
# 3                               6645167.2                           0.007983
# 4                               7232000.6                           0.013256
#
#    limited_access_to_healthy_foods uninsured_adults  \
# 0                                          0.019016
# 1                                          0.023866
# 2                                          0.008422
# 3                                          0.018778
# 4                                          0.020725
#
#    limited_access_to_healthy_foods uninsured_children  \
# 0                                           0.005002
# 1                                           0.005648
# 2                                           0.002257
# 3                                           0.006183
# 4                                           0.005385
#
#    limited_access_to_healthy_foods other_primary_care_providers  \
# 0                                           0.000108
# 1                                           0.000146
# 2                                           0.000065
# 3                                           0.000050
# 4                                           0.000069
#
#    limited_access_to_healthy_foods median_household_income  \
# 0                                        4646.967963
# 1                                        4140.269719
# 2                                        1849.575977
# 3                                        3164.941818
# 4                                        4047.941735
#
#    uninsured_adults^2  uninsured_adults uninsured_children  \
# 0            0.031825                             0.008371
# 1            0.032024                             0.007578
# 2            0.032394                             0.008682
# 3            0.044167                             0.014542
# 4            0.032402                             0.008419
#
#    uninsured_adults other_primary_care_providers  \
# 0                                       0.000181
# 1                                       0.000196
# 2                                       0.000252
# 3                                       0.000118
# 4                                       0.000107
#
#    uninsured_adults median_household_income  uninsured_children^2  \
# 0                               7777.154072              0.002202
# 1                               5555.397014              0.001793
# 2                               7114.381262              0.002327
# 3                               7444.264938              0.004788
# 4                               6328.644148              0.002188
#
#    uninsured_children other_primary_care_providers  \
# 0                                         0.000048
# 1                                         0.000046
# 2                                         0.000067
# 3                                         0.000039
# 4                                         0.000028
#
#    uninsured_children median_household_income  other_primary_care_providers^2  \
# 0                                 2045.573435                    1.031680e-06
# 1                                 1314.641903                    1.202681e-06
# 2                                 1906.803841                    1.952933e-06
# 3                                 2451.075894                    3.162763e-07
# 4                                 1644.440767                    3.544234e-07
#
#    other_primary_care_providers median_household_income  \
# 0                                          44.280165
# 1                                          34.044964
# 2                                          55.239344
# 3                                          19.920784
# 4                                          20.930777
#
#    median_household_income^2
# 0               1.900524e+09
# 1               9.637299e+08
# 2               1.562463e+09
# 3               1.254718e+09
# 4               1.236085e+09

# %%
df_poly2.shape
# Out:
# (83, 170)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(df_poly2, target, random_state=25,test_size=0.2)

# %%
scaler2 = StandardScaler()
scaled = scaler2.fit(X_train2)

X_train2 = pd.DataFrame(data=scaler2.transform(X_train2), columns=df_poly2.columns)

X_test2 = pd.DataFrame(data=scaler2.transform(X_test2), columns=df_poly2.columns)

# %%
X_test2.head()
# Out:
#    adult_smoking  adult_obesity  physical_inactivity  excessive_drinking  \
# 0       0.530695      -0.753940             0.223850           -0.783713
# 1      -0.212692      -0.222883            -0.493037           -0.937009
# 2      -0.032461      -0.435306            -1.365768           -0.467156
# 3       0.869928      -0.408753            -0.524206            0.437591
# 4      -0.803997      -0.647729            -1.241092            0.916868
#
#    uninsured_under_65  primary_care_physicians  dentists  \
# 0           -0.207188                -0.116308  1.264953
# 1            0.377328                 0.352843 -1.069037
# 2            0.503580                -0.197443 -0.569610
# 3           -0.495216                 0.441988  0.746227
# 4            0.870980                 0.318222  0.069740
#
#    mental_health_providers  flu_vaccinations  unemployed  diabetes_prevalence  \
# 0                 2.317867         -0.365548    0.015911             0.316245
# 1                 0.648601          0.692617    0.424981             0.847343
# 2                -0.413739         -0.153915   -0.219963            -0.002414
# 3                 0.388537          0.269351   -0.461550            -0.533512
# 4                -0.730641          0.269351   -1.246190            -1.861257
#
#    hiv_prevalence  limited_access_to_healthy_foods  uninsured_adults  \
# 0        0.925293                        -0.176053          0.098058
# 1       -0.070844                         0.692864          0.327150
# 2       -0.093004                         1.077791          0.516063
# 3        0.484735                         0.061637         -0.481517
# 4       -0.783653                        -0.533032          0.822719
#
#    uninsured_children  other_primary_care_providers  median_household_income  \
# 0           -0.597911                      1.011982                -0.740788
# 1           -0.019996                     -0.770797                -0.354487
# 2            0.316586                     -0.451917                -1.131369
# 3           -0.426451                      0.498051                 0.474429
# 4            1.528704                      1.215025                 0.845909
#
#    adult_smoking^2  adult_smoking adult_obesity  \
# 0         0.462850                    -0.111642
# 1        -0.256787                    -0.263852
# 2        -0.088137                    -0.262219
# 3         0.812313                     0.249855
# 4        -0.783927                    -0.778869
#
#    adult_smoking physical_inactivity  adult_smoking excessive_drinking  \
# 0                           0.468067                         -0.470087
# 1                          -0.431077                         -1.512119
# 2                          -0.790495                         -0.610109
# 3                           0.251049                          1.947632
# 4                          -1.183860                          0.392524
#
#    adult_smoking uninsured_under_65  adult_smoking primary_care_physicians  \
# 0                          0.142147                              -0.007648
# 1                          0.074141                               0.344192
# 2                          0.262175                              -0.196068
# 3                          0.136948                               0.711208
# 4                         -0.010367                               0.167753
#
#    adult_smoking dentists  adult_smoking mental_health_providers  \
# 0                1.520193                               2.533187
# 1               -1.105994                               0.614339
# 2               -0.576551                              -0.417634
# 3                1.067767                               0.518433
# 4               -0.116836                              -0.743418
#
#    adult_smoking flu_vaccinations  adult_smoking unemployed  \
# 0                       -0.091215                  0.089056
# 1                        0.726976                  0.166832
# 2                       -0.121710                 -0.216565
# 3                        0.872149                 -0.181203
# 4                       -0.079516                 -1.030917
#
#    adult_smoking diabetes_prevalence  adult_smoking hiv_prevalence  \
# 0                           0.455328                      0.917322
# 1                           0.321728                     -0.127455
# 2                          -0.055650                     -0.119719
# 3                           0.110273                      0.575950
# 4                          -1.456791                     -0.782888
#
#    adult_smoking limited_access_to_healthy_foods  \
# 0                                      -0.130489
# 1                                       0.488016
# 2                                       0.848129
# 3                                       0.132094
# 4                                      -0.566612
#
#    adult_smoking uninsured_adults  adult_smoking uninsured_children  \
# 0                        0.327916                         -0.183895
# 1                        0.039709                         -0.137241
# 2                        0.260623                          0.266211
# 3                        0.130436                          0.177096
# 4                       -0.034673                          0.678381
#
#    adult_smoking other_primary_care_providers  \
# 0                                    1.209094
# 1                                   -0.793533
# 2                                   -0.451160
# 3                                    0.754248
# 4                                    0.935207
#
#    adult_smoking median_household_income  adult_obesity^2  \
# 0                              -0.654772        -0.751959
# 1                              -0.568314        -0.261799
# 2                              -1.634589        -0.461112
# 3                               1.654276        -0.436435
# 4                               0.673954        -0.656093
#
#    adult_obesity physical_inactivity  adult_obesity excessive_drinking  \
# 0                          -0.360693                         -1.716079
# 1                          -0.449899                         -1.471226
# 2                          -1.073951                         -0.986881
# 3                          -0.575800                          0.324419
# 4                          -1.116392                          0.736232
#
#    adult_obesity uninsured_under_65  adult_obesity primary_care_physicians  \
# 0                         -0.550431                              -0.214186
# 1                          0.106253                               0.373611
# 2                          0.072013                              -0.250675
# 3                         -0.562562                               0.429758
# 4                          0.187078                               0.250624
#
#    adult_obesity dentists  adult_obesity mental_health_providers  \
# 0                1.103758                               2.240565
# 1               -1.143780                               0.681794
# 2               -0.655261                              -0.430814
# 3                0.691290                               0.388027
# 4               -0.049823                              -0.754917
#
#    adult_obesity flu_vaccinations  adult_obesity unemployed  \
# 0                       -0.653794                 -0.211324
# 1                        0.723778                  0.211247
# 2                       -0.300280                 -0.305288
# 3                        0.169919                 -0.472511
# 4                        0.059524                 -1.067830
#
#    adult_obesity diabetes_prevalence  adult_obesity hiv_prevalence  \
# 0                          -0.227730                      0.632235
# 1                           0.367576                     -0.125022
# 2                          -0.253763                     -0.170624
# 3                          -0.557404                      0.328135
# 4                          -1.439862                     -0.774564
#
#    adult_obesity limited_access_to_healthy_foods  \
# 0                                      -0.269206
# 1                                       0.552367
# 2                                       0.843893
# 3                                      -0.026639
# 4                                      -0.557932
#
#    adult_obesity uninsured_adults  adult_obesity uninsured_children  \
# 0                       -0.347757                         -0.928751
# 1                        0.064712                         -0.129568
# 2                        0.073320                          0.047142
# 3                       -0.538369                         -0.597128
# 4                        0.148766                          0.969587
#
#    adult_obesity other_primary_care_providers  \
# 0                                    0.879435
# 1                                   -0.833689
# 2                                   -0.529488
# 3                                    0.453469
# 4                                    1.115464
#
#    adult_obesity median_household_income  physical_inactivity^2  \
# 0                              -1.334541               0.179401
# 1                              -0.528678              -0.535074
# 2                              -1.706640              -1.336728
# 3                               0.501000              -0.564993
# 4                               0.835074              -1.226787
#
#    physical_inactivity excessive_drinking  \
# 0                               -0.690871
# 1                               -1.337488
# 2                               -1.438813
# 3                                0.138084
# 4                                0.044397
#
#    physical_inactivity uninsured_under_65  \
# 0                               -0.057498
# 1                               -0.037186
# 2                               -0.443978
# 3                               -0.633009
# 4                               -0.148154
#
#    physical_inactivity primary_care_physicians  physical_inactivity dentists  \
# 0                                    -0.046517                      1.582534
# 1                                     0.365047                     -1.229981
# 2                                    -0.387799                     -0.818057
# 3                                     0.458305                      0.747578
# 4                                     0.167242                     -0.152476
#
#    physical_inactivity mental_health_providers  \
# 0                                     2.595380
# 1                                     0.648505
# 2                                    -0.477680
# 3                                     0.377954
# 4                                    -0.772422
#
#    physical_inactivity flu_vaccinations  physical_inactivity unemployed  \
# 0                             -0.267711                        0.052287
# 1                              0.481594                        0.203288
# 2                             -0.617344                       -0.567866
# 3                              0.074055                       -0.558616
# 4                             -0.208232                       -1.342895
#
#    physical_inactivity diabetes_prevalence  \
# 0                                 0.274558
# 1                                 0.226782
# 2                                -0.711705
# 3                                -0.615645
# 4                                -1.680015
#
#    physical_inactivity hiv_prevalence  \
# 0                            0.980021
# 1                           -0.135991
# 2                           -0.275478
# 3                            0.386641
# 4                           -0.865461
#
#    physical_inactivity limited_access_to_healthy_foods  \
# 0                                          -0.146510
# 1                                           0.563238
# 2                                           0.712643
# 3                                          -0.015871
# 4                                          -0.613504
#
#    physical_inactivity uninsured_adults  \
# 0                              0.156676
# 1                             -0.068293
# 2                             -0.426902
# 3                             -0.621931
# 4                             -0.169122
#
#    physical_inactivity uninsured_children  \
# 0                               -0.389067
# 1                               -0.265424
# 2                               -0.455006
# 3                               -0.587726
# 4                                0.457424
#
#    physical_inactivity other_primary_care_providers  \
# 0                                          1.163715
# 1                                         -0.850642
# 2                                         -0.650764
# 3                                          0.426435
# 4                                          0.925358
#
#    physical_inactivity median_household_income  excessive_drinking^2  \
# 0                                    -0.791489             -0.805894
# 1                                    -0.636337             -0.938694
# 2                                    -1.954991             -0.520773
# 3                                     0.375467              0.375016
# 4                                     0.366196              0.898111
#
#    excessive_drinking uninsured_under_65  \
# 0                              -0.873231
# 1                              -0.589026
# 2                              -0.005945
# 3                               0.029319
# 4                               1.794168
#
#    excessive_drinking primary_care_physicians  excessive_drinking dentists  \
# 0                                   -0.259585                     0.721243
# 1                                    0.053287                    -1.010847
# 2                                   -0.267636                    -0.573604
# 3                                    0.453669                     0.743816
# 4                                    0.452695                     0.263981
#
#    excessive_drinking mental_health_providers  \
# 0                                    1.743360
# 1                                    0.387765
# 2                                   -0.409107
# 3                                    0.406599
# 4                                   -0.657748
#
#    excessive_drinking flu_vaccinations  excessive_drinking unemployed  \
# 0                            -0.613792                      -0.371011
# 1                            -0.001750                       0.035032
# 2                            -0.349131                      -0.474885
# 3                             0.345328                      -0.281853
# 4                             0.559798                      -1.294736
#
#    excessive_drinking diabetes_prevalence  excessive_drinking hiv_prevalence  \
# 0                               -0.629863                           0.717529
# 1                               -0.317360                          -0.238590
# 2                               -0.522094                          -0.157267
# 3                                0.064719                           0.681919
# 4                               -1.070953                          -0.679918
#
#    excessive_drinking limited_access_to_healthy_foods  \
# 0                                          -0.296417
# 1                                           0.505877
# 2                                           1.065988
# 3                                           0.230344
# 4                                          -0.405842
#
#    excessive_drinking uninsured_adults  excessive_drinking uninsured_children  \
# 0                            -0.658927                              -0.928139
# 1                            -0.638671                              -0.657500
# 2                             0.021931                              -0.111600
# 3                             0.046543                              -0.047808
# 4                             1.848674                               1.878160
#
#    excessive_drinking other_primary_care_providers  \
# 0                                         0.583466
# 1                                        -0.826479
# 2                                        -0.501166
# 3                                         0.550094
# 4                                         1.411343
#
#    excessive_drinking median_household_income  uninsured_under_65^2  \
# 0                                   -0.782820             -0.270423
# 1                                   -0.628158              0.324118
# 2                                   -0.903594              0.458346
# 3                                    0.405467             -0.547120
# 4                                    0.871787              0.860696
#
#    uninsured_under_65 primary_care_physicians  uninsured_under_65 dentists  \
# 0                                   -0.109400                     1.403886
# 1                                    0.610996                    -1.101843
# 2                                   -0.057877                    -0.481389
# 3                                    0.457087                     0.716704
# 4                                    0.708572                     0.400581
#
#    uninsured_under_65 mental_health_providers  \
# 0                                    2.452492
# 1                                    0.813714
# 2                                   -0.384642
# 3                                    0.371770
# 4                                   -0.745260
#
#    uninsured_under_65 flu_vaccinations  uninsured_under_65 unemployed  \
# 0                            -0.426618                      -0.084547
# 1                             1.008110                       0.460787
# 2                             0.142962                      -0.053343
# 3                             0.059555                      -0.545988
# 4                             0.818202                      -0.873445
#
#    uninsured_under_65 diabetes_prevalence  uninsured_under_65 hiv_prevalence  \
# 0                                0.018729                           0.902904
# 1                                0.718925                           0.015332
# 2                                0.269102                           0.014755
# 3                               -0.634487                           0.386612
# 4                               -0.729046                          -0.707373
#
#    uninsured_under_65 limited_access_to_healthy_foods  \
# 0                                          -0.201066
# 1                                           0.759512
# 2                                           1.184553
# 3                                          -0.031379
# 4                                          -0.418702
#
#    uninsured_under_65 uninsured_adults  uninsured_under_65 uninsured_children  \
# 0                            -0.119386                              -0.494690
# 1                             0.301069                               0.117140
# 2                             0.470096                               0.389734
# 3                            -0.543458                              -0.523984
# 4                             0.841628                               1.373270
#
#    uninsured_under_65 other_primary_care_providers  \
# 0                                         0.979824
# 1                                        -0.717985
# 2                                        -0.352663
# 3                                         0.379390
# 4                                         1.613024
#
#    uninsured_under_65 median_household_income  primary_care_physicians^2  \
# 0                                   -1.058558                  -0.274427
# 1                                   -0.121970                   0.041533
# 2                                   -1.182704                  -0.319940
# 3                                    0.339297                   0.111747
# 4                                    2.083542                   0.015141
#
#    primary_care_physicians dentists  \
# 0                          0.167261
# 1                         -0.423957
# 2                         -0.387053
# 3                          0.325762
# 4                          0.001099
#
#    primary_care_physicians mental_health_providers  \
# 0                                         0.992387
# 1                                         0.399495
# 2                                        -0.390140
# 3                                         0.263904
# 4                                        -0.523707
#
#    primary_care_physicians flu_vaccinations  \
# 0                                 -0.253353
# 1                                  0.474662
# 2                                 -0.253681
# 3                                  0.388719
# 4                                  0.286254
#
#    primary_care_physicians unemployed  \
# 0                           -0.051254
# 1                            0.740759
# 2                           -0.251791
# 3                            0.238709
# 4                           -0.387373
#
#    primary_care_physicians diabetes_prevalence  \
# 0                                    -0.015025
# 1                                     0.705832
# 2                                    -0.176583
# 3                                     0.422506
# 4                                    -0.073434
#
#    primary_care_physicians hiv_prevalence  \
# 0                                0.548484
# 1                                0.189706
# 2                               -0.201999
# 3                                0.780487
# 4                               -0.470884
#
#    primary_care_physicians limited_access_to_healthy_foods  \
# 0                                          -0.205163
# 1                                           0.854890
# 2                                           0.548238
# 3                                           0.347403
# 4                                          -0.266475
#
#    primary_care_physicians uninsured_adults  \
# 0                                 -0.046790
# 1                                  0.592050
# 2                                 -0.058055
# 3                                  0.453187
# 4                                  0.692579
#
#    primary_care_physicians uninsured_children  \
# 0                                   -0.210869
# 1                                    0.453042
# 2                                   -0.076526
# 3                                    0.409693
# 4                                    0.921822
#
#    primary_care_physicians other_primary_care_providers  \
# 0                                           0.296436
# 1                                          -0.348056
# 2                                          -0.395568
# 3                                           0.475958
# 4                                           0.805761
#
#    primary_care_physicians median_household_income  dentists^2  \
# 0                                        -0.301214    1.030546
# 1                                         0.072257   -0.749882
# 2                                        -0.427095   -0.539541
# 3                                         0.381077    0.459485
# 4                                         0.395647   -0.134675
#
#    dentists mental_health_providers  dentists flu_vaccinations  \
# 0                          2.855546                   0.704674
# 1                         -0.211134                  -0.755274
# 2                         -0.466813                  -0.532000
# 3                          0.473857                   0.684550
# 4                         -0.599503                   0.119867
#
#    dentists unemployed  dentists diabetes_prevalence  dentists hiv_prevalence  \
# 0             1.342020                      1.657795                 1.822111
# 1            -0.863059                     -1.076291                -0.683536
# 2            -0.582432                     -0.607516                -0.422852
# 3             0.422509                      0.705365                 0.883193
# 4            -0.645675                     -0.409897                -0.616303
#
#    dentists limited_access_to_healthy_foods  dentists uninsured_adults  \
# 0                                  0.567718                   1.517271
# 1                                 -0.398288                  -1.101217
# 2                                  0.330498                  -0.479587
# 3                                  0.570681                   0.699679
# 4                                 -0.441603                   0.375764
#
#    dentists uninsured_children  dentists other_primary_care_providers  \
# 0                     1.147633                               1.519118
# 1                    -1.113621                              -0.845503
# 2                    -0.476361                              -0.567198
# 3                     0.707190                               0.693411
# 4                     0.707469                               0.659876
#
#    dentists median_household_income  mental_health_providers^2  \
# 0                          0.415822                   2.045718
# 1                         -0.823517                   0.121167
# 2                         -0.683402                  -0.377257
# 3                          0.636689                  -0.053074
# 4                          0.251055                  -0.416532
#
#    mental_health_providers flu_vaccinations  \
# 0                                  1.545246
# 1                                  0.673690
# 2                                 -0.381798
# 3                                  0.328196
# 4                                 -0.613376
#
#    mental_health_providers unemployed  \
# 0                            2.448983
# 1                            0.904124
# 2                           -0.435191
# 3                            0.243750
# 4                           -0.771637
#
#    mental_health_providers diabetes_prevalence  \
# 0                                     2.698312
# 1                                     0.910102
# 2                                    -0.419227
# 3                                     0.369094
# 4                                    -0.787658
#
#    mental_health_providers hiv_prevalence  \
# 0                                2.545830
# 1                                0.286921
# 2                               -0.336242
# 3                                0.411385
# 4                               -0.543456
#
#    mental_health_providers limited_access_to_healthy_foods  \
# 0                                           0.961337
# 1                                           0.658517
# 2                                          -0.158450
# 3                                           0.141822
# 4                                          -0.525576
#
#    mental_health_providers uninsured_adults  \
# 0                                  2.593167
# 1                                  0.806770
# 2                                 -0.384164
# 3                                  0.373855
# 4                                 -0.747293
#
#    mental_health_providers uninsured_children  \
# 0                                    2.247891
# 1                                    0.746798
# 2                                   -0.385968
# 3                                    0.377994
# 4                                   -0.730754
#
#    mental_health_providers other_primary_care_providers  \
# 0                                           1.827313
# 1                                          -0.124144
# 2                                          -0.384498
# 3                                           0.211588
# 4                                          -0.459806
#
#    mental_health_providers median_household_income  flu_vaccinations^2  \
# 0                                         1.608756           -0.492155
# 1                                         0.468635            0.643901
# 2                                        -0.486715           -0.288861
# 3                                         0.462834            0.153603
# 4                                        -0.662510            0.153603
#
#    flu_vaccinations unemployed  flu_vaccinations diabetes_prevalence  \
# 0                    -0.179557                             -0.191656
# 1                     1.513400                              1.269085
# 2                    -0.245937                             -0.115697
# 3                    -0.167303                              0.040602
# 4                    -1.219871                             -0.671509
#
#    flu_vaccinations hiv_prevalence  \
# 0                         0.801006
# 1                         0.247739
# 2                        -0.110852
# 3                         0.721141
# 4                        -0.742767
#
#    flu_vaccinations limited_access_to_healthy_foods  \
# 0                                         -0.261140
# 1                                          1.208351
# 2                                          1.111641
# 3                                          0.230975
# 4                                         -0.456205
#
#    flu_vaccinations uninsured_adults  flu_vaccinations uninsured_children  \
# 0                          -0.282170                            -0.627650
# 1                           1.005364                             0.659870
# 2                           0.162152                             0.057048
# 3                           0.069589                             0.014933
# 4                           0.820172                             1.219714
#
#    flu_vaccinations other_primary_care_providers  \
# 0                                       0.534497
# 1                                      -0.485689
# 2                                      -0.426320
# 3                                       0.469398
# 4                                       1.058768
#
#    flu_vaccinations median_household_income  unemployed^2  \
# 0                                 -0.636630     -0.104661
# 1                                  0.125274      0.215860
# 2                                 -0.731722     -0.271778
# 3                                  0.365585     -0.429523
# 4                                  0.576580     -0.848176
#
#    unemployed diabetes_prevalence  unemployed hiv_prevalence  \
# 0                        0.066389                   0.604945
# 1                        0.584013                   0.019547
# 2                       -0.216364                  -0.203434
# 3                       -0.544380                   0.073088
# 4                       -1.363484                  -0.828498
#
#    unemployed limited_access_to_healthy_foods  unemployed uninsured_adults  \
# 0                                   -0.195501                     0.015481
# 1                                    0.589788                     0.442918
# 2                                    0.541292                    -0.049120
# 3                                   -0.183670                    -0.547917
# 4                                   -0.679707                    -0.884694
#
#    unemployed uninsured_children  unemployed other_primary_care_providers  \
# 0                      -0.248633                                 1.040162
# 1                       0.395414                                -0.558805
# 2                      -0.051530                                -0.478834
# 3                      -0.578477                                 0.202851
# 4                      -0.705229                                 0.064436
#
#    unemployed median_household_income  diabetes_prevalence^2  \
# 0                           -0.622048               0.260568
# 1                            0.442665               0.831100
# 2                           -1.366268              -0.064846
# 3                           -0.037814              -0.579029
# 4                           -1.180688              -1.710408
#
#    diabetes_prevalence hiv_prevalence  \
# 0                            0.973984
# 1                            0.068933
# 2                           -0.096715
# 3                            0.332884
# 4                           -0.917397
#
#    diabetes_prevalence limited_access_to_healthy_foods  \
# 0                                          -0.138568
# 1                                           0.802699
# 2                                           0.950172
# 3                                          -0.055149
# 4                                          -0.686301
#
#    diabetes_prevalence uninsured_adults  \
# 0                              0.203454
# 1                              0.666772
# 2                              0.270262
# 3                             -0.619999
# 4                             -0.731059
#
#    diabetes_prevalence uninsured_children  \
# 0                               -0.288101
# 1                                0.466986
# 2                                0.225187
# 3                               -0.615696
# 4                               -0.216738
#
#    diabetes_prevalence other_primary_care_providers  \
# 0                                          1.293326
# 1                                         -0.694278
# 2                                         -0.462206
# 3                                          0.425332
# 4                                          0.612480
#
#    diabetes_prevalence median_household_income  hiv_prevalence^2  \
# 0                                    -0.793942          0.571797
# 1                                     0.236254         -0.264100
# 2                                    -1.620434         -0.277753
# 3                                     0.380185          0.148502
# 4                                    -0.406724         -0.595460
#
#    hiv_prevalence limited_access_to_healthy_foods  \
# 0                                        0.196874
# 1                                        0.201461
# 2                                        0.368775
# 3                                        0.173069
# 4                                       -0.601440
#
#    hiv_prevalence uninsured_adults  hiv_prevalence uninsured_children  \
# 0                         0.949907                           0.895549
# 1                        -0.007947                          -0.005233
# 2                         0.003341                           0.056668
# 3                         0.359325                           0.492677
# 4                        -0.699376                          -0.632353
#
#    hiv_prevalence other_primary_care_providers  \
# 0                                     1.244617
# 1                                    -0.482320
# 2                                    -0.345939
# 3                                     0.514364
# 4                                    -0.270160
#
#    hiv_prevalence median_household_income  limited_access_to_healthy_foods^2  \
# 0                                0.635781                          -0.339273
# 1                               -0.145888                           0.329358
# 2                               -0.450308                           0.737586
# 3                                0.850088                          -0.191196
# 4                               -0.658753                          -0.512391
#
#    limited_access_to_healthy_foods uninsured_adults  \
# 0                                         -0.157318
# 1                                          0.734179
# 2                                          1.171650
# 3                                         -0.034435
# 4                                         -0.421546
#
#    limited_access_to_healthy_foods uninsured_children  \
# 0                                          -0.260640
# 1                                           0.800876
# 2                                           1.361265
# 3                                           0.015839
# 4                                          -0.291785
#
#    limited_access_to_healthy_foods other_primary_care_providers  \
# 0                                           0.458226
# 1                                          -0.132663
# 2                                           0.419768
# 3                                           0.421547
# 4                                           0.072014
#
#    limited_access_to_healthy_foods median_household_income  \
# 0                                          -0.379252
# 1                                           0.760730
# 2                                           0.643759
# 3                                           0.385638
# 4                                          -0.350175
#
#    uninsured_adults^2  uninsured_adults uninsured_children  \
# 0            0.033417                            -0.364531
# 1            0.269995                             0.108927
# 2            0.470271                             0.423735
# 3           -0.534285                            -0.529336
# 4            0.805362                             1.408469
#
#    uninsured_adults other_primary_care_providers  \
# 0                                       1.081071
# 1                                      -0.724337
# 2                                      -0.351738
# 3                                       0.373050
# 4                                       1.582541
#
#    uninsured_adults median_household_income  uninsured_children^2  \
# 0                                 -0.887336             -0.631965
# 1                                 -0.148184             -0.097164
# 2                                 -1.208677              0.238235
# 3                                  0.370799             -0.478713
# 4                                  2.151318              1.592005
#
#    uninsured_children other_primary_care_providers  \
# 0                                         0.834092
# 1                                        -0.791792
# 2                                        -0.372456
# 3                                         0.403514
# 4                                         2.134049
#
#    uninsured_children median_household_income  other_primary_care_providers^2  \
# 0                                   -0.980892                        0.692027
# 1                                   -0.332064                       -0.599668
# 2                                   -0.879995                       -0.456049
# 3                                    0.136101                        0.197540
# 4                                    1.912493                        0.914651
#
#    other_primary_care_providers median_household_income  \
# 0                                           0.433917
# 1                                          -0.752081
# 2                                          -0.711563
# 3                                           0.627746
# 4                                           1.534061
#
#    median_household_income^2
# 0                  -0.687904
# 1                  -0.395411
# 2                  -0.953116
# 3                   0.333541
# 4                   0.705078

# %%
lm_2 = LinearRegression()

lm_2 = lm_2.fit(X_train2, y_train2)

y_train_pred2 = lm_2.predict(X_train2)

train2_rmse = np.sqrt(metrics.mean_squared_error(y_train2, y_train_pred2))

print('Training Root Mean Squared Error:' , train2_rmse)
# Out:
# Training Root Mean Squared Error: 2.4737922779493408e-14

# %%
y_pred2 = lm_2.predict(X_test2)

test2_rmse = np.sqrt(metrics.mean_squared_error(y_test2, y_pred2))

print('Testing Root Mean Squared Error:' , test2_rmse)
# Out:
# Testing Root Mean Squared Error: 1.9080889957538718

# %%
print('Training: ', int(train2_rmse), "vs. Testing: ", int(test2_rmse))
# Out:
# Training:  0 vs. Testing:  1

# %%
# Create correlation matrix
corr_matrix = X_train.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
#                                  adult_smoking  adult_obesity  \
# adult_smoking                              NaN       0.673136
# adult_obesity                              NaN            NaN
# physical_inactivity                        NaN            NaN
# excessive_drinking                         NaN            NaN
# uninsured_under_65                         NaN            NaN
# primary_care_physicians                    NaN            NaN
# dentists                                   NaN            NaN
# mental_health_providers                    NaN            NaN
# flu_vaccinations                           NaN            NaN
# unemployed                                 NaN            NaN
# diabetes_prevalence                        NaN            NaN
# hiv_prevalence                             NaN            NaN
# limited_access_to_healthy_foods            NaN            NaN
# uninsured_adults                           NaN            NaN
# uninsured_children                         NaN            NaN
# other_primary_care_providers               NaN            NaN
# median_household_income                    NaN            NaN
#
#                                  physical_inactivity  excessive_drinking  \
# adult_smoking                               0.352585            0.739625
# adult_obesity                               0.418700            0.739939
# physical_inactivity                              NaN            0.521405
# excessive_drinking                               NaN                 NaN
# uninsured_under_65                               NaN                 NaN
# primary_care_physicians                          NaN                 NaN
# dentists                                         NaN                 NaN
# mental_health_providers                          NaN                 NaN
# flu_vaccinations                                 NaN                 NaN
# unemployed                                       NaN                 NaN
# diabetes_prevalence                              NaN                 NaN
# hiv_prevalence                                   NaN                 NaN
# limited_access_to_healthy_foods                  NaN                 NaN
# uninsured_adults                                 NaN                 NaN
# uninsured_children                               NaN                 NaN
# other_primary_care_providers                     NaN                 NaN
# median_household_income                          NaN                 NaN
#
#                                  uninsured_under_65  primary_care_physicians  \
# adult_smoking                              0.401328                 0.153999
# adult_obesity                              0.411217                 0.277568
# physical_inactivity                        0.409043                 0.475001
# excessive_drinking                         0.405195                 0.198676
# uninsured_under_65                              NaN                 0.490489
# primary_care_physicians                         NaN                      NaN
# dentists                                        NaN                      NaN
# mental_health_providers                         NaN                      NaN
# flu_vaccinations                                NaN                      NaN
# unemployed                                      NaN                      NaN
# diabetes_prevalence                             NaN                      NaN
# hiv_prevalence                                  NaN                      NaN
# limited_access_to_healthy_foods                 NaN                      NaN
# uninsured_adults                                NaN                      NaN
# uninsured_children                              NaN                      NaN
# other_primary_care_providers                    NaN                      NaN
# median_household_income                         NaN                      NaN
#
#                                  dentists  mental_health_providers  \
# adult_smoking                    0.102700                 0.000250
# adult_obesity                    0.130651                 0.259157
# physical_inactivity              0.426479                 0.247454
# excessive_drinking               0.172009                 0.093599
# uninsured_under_65               0.438540                 0.248654
# primary_care_physicians          0.743978                 0.385293
# dentists                              NaN                 0.300522
# mental_health_providers               NaN                      NaN
# flu_vaccinations                      NaN                      NaN
# unemployed                            NaN                      NaN
# diabetes_prevalence                   NaN                      NaN
# hiv_prevalence                        NaN                      NaN
# limited_access_to_healthy_foods       NaN                      NaN
# uninsured_adults                      NaN                      NaN
# uninsured_children                    NaN                      NaN
# other_primary_care_providers          NaN                      NaN
# median_household_income               NaN                      NaN
#
#                                  flu_vaccinations  unemployed  \
# adult_smoking                            0.510936    0.724442
# adult_obesity                            0.484245    0.636784
# physical_inactivity                      0.170484    0.270385
# excessive_drinking                       0.446557    0.631094
# uninsured_under_65                       0.393359    0.271676
# primary_care_physicians                  0.298038    0.197719
# dentists                                 0.220439    0.241531
# mental_health_providers                  0.214342    0.073235
# flu_vaccinations                              NaN    0.542422
# unemployed                                    NaN         NaN
# diabetes_prevalence                           NaN         NaN
# hiv_prevalence                                NaN         NaN
# limited_access_to_healthy_foods               NaN         NaN
# uninsured_adults                              NaN         NaN
# uninsured_children                            NaN         NaN
# other_primary_care_providers                  NaN         NaN
# median_household_income                       NaN         NaN
#
#                                  diabetes_prevalence  hiv_prevalence  \
# adult_smoking                               0.517273        0.311058
# adult_obesity                               0.608462        0.381307
# physical_inactivity                         0.636908        0.028415
# excessive_drinking                          0.716386        0.264476
# uninsured_under_65                          0.483599        0.131363
# primary_care_physicians                     0.384073        0.000170
# dentists                                    0.352381        0.122598
# mental_health_providers                     0.239717        0.163865
# flu_vaccinations                            0.353403        0.177187
# unemployed                                  0.447098        0.293712
# diabetes_prevalence                              NaN        0.057687
# hiv_prevalence                                   NaN             NaN
# limited_access_to_healthy_foods                  NaN             NaN
# uninsured_adults                                 NaN             NaN
# uninsured_children                               NaN             NaN
# other_primary_care_providers                     NaN             NaN
# median_household_income                          NaN             NaN
#
#                                  limited_access_to_healthy_foods  \
# adult_smoking                                           0.478449
# adult_obesity                                           0.324803
# physical_inactivity                                     0.038420
# excessive_drinking                                      0.346137
# uninsured_under_65                                      0.010133
# primary_care_physicians                                 0.016091
# dentists                                                0.023950
# mental_health_providers                                 0.259431
# flu_vaccinations                                        0.193637
# unemployed                                              0.362677
# diabetes_prevalence                                     0.204684
# hiv_prevalence                                          0.292152
# limited_access_to_healthy_foods                              NaN
# uninsured_adults                                             NaN
# uninsured_children                                           NaN
# other_primary_care_providers                                 NaN
# median_household_income                                      NaN
#
#                                  uninsured_adults  uninsured_children  \
# adult_smoking                            0.475138            0.166294
# adult_obesity                            0.528262            0.180007
# physical_inactivity                      0.437785            0.142830
# excessive_drinking                       0.477645            0.106173
# uninsured_under_65                       0.972886            0.664447
# primary_care_physicians                  0.452838            0.383340
# dentists                                 0.368839            0.452160
# mental_health_providers                  0.246128            0.249415
# flu_vaccinations                         0.427741            0.173324
# unemployed                               0.287420            0.100151
# diabetes_prevalence                      0.537001            0.098084
# hiv_prevalence                           0.016325            0.443933
# limited_access_to_healthy_foods          0.045924            0.328487
# uninsured_adults                              NaN            0.531032
# uninsured_children                            NaN                 NaN
# other_primary_care_providers                  NaN                 NaN
# median_household_income                       NaN                 NaN
#
#                                  other_primary_care_providers  \
# adult_smoking                                        0.072670
# adult_obesity                                        0.178504
# physical_inactivity                                  0.214471
# excessive_drinking                                   0.155877
# uninsured_under_65                                   0.151614
# primary_care_physicians                              0.285223
# dentists                                             0.301762
# mental_health_providers                              0.511248
# flu_vaccinations                                     0.187390
# unemployed                                           0.160911
# diabetes_prevalence                                  0.300549
# hiv_prevalence                                       0.270813
# limited_access_to_healthy_foods                      0.069726
# uninsured_adults                                     0.108944
# uninsured_children                                   0.223614
# other_primary_care_providers                              NaN
# median_household_income                                   NaN
#
#                                  median_household_income
# adult_smoking                                   0.741837
# adult_obesity                                   0.715195
# physical_inactivity                             0.586642
# excessive_drinking                              0.829875
# uninsured_under_65                              0.579787
# primary_care_physicians                         0.389605
# dentists                                        0.390057
# mental_health_providers                         0.059103
# flu_vaccinations                                0.462865
# unemployed                                      0.614938
# diabetes_prevalence                             0.711568
# hiv_prevalence                                  0.246393
# limited_access_to_healthy_foods                 0.364103
# uninsured_adults                                0.633426
# uninsured_children                              0.008750
# other_primary_care_providers                    0.088139
# median_household_income                              NaN

# %%
sns.set(style="white")


# Compute the correlation matrix
corr = X_train.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
len(X_train.columns)
# Out:
# 17

# %%
# Find index of feature columns with correlation greater than 0.90
to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]

#if you change inplace to True it will go through and drop all of those columns from the dataset
X_train.drop(columns=to_drop, inplace=False)
X_test.drop(columns=to_drop, inplace=False)
# Out:
#     adult_smoking  adult_obesity  physical_inactivity  excessive_drinking  \
# 0        0.530695      -0.753940             0.223850           -0.783713
# 1       -0.212692      -0.222883            -0.493037           -0.937009
# 2       -0.032461      -0.435306            -1.365768           -0.467156
# 3        0.869928      -0.408753            -0.524206            0.437591
# 4       -0.803997      -0.647729            -1.241092            0.916868
# 5        0.256126      -0.169777             1.626454            0.051868
# 6        1.075490       0.069198             0.535540           -0.998651
# 7        0.977227       0.308174            -0.306023           -1.098729
# 8        0.974156       0.016093             0.068005           -0.956382
# 9       -0.246389      -0.727388            -2.643696            1.297028
# 10       0.665895       1.078207             0.753723           -0.329652
# 11       0.189722       0.201963            -0.181347           -0.251626
# 12      -0.078322       0.361280            -0.243685           -0.406185
# 13      -0.524347       0.122304            -0.399530           -0.227965
# 14      -1.225518      -1.311551            -0.680050           -0.219473
# 15       2.212639       0.812679             1.626454           -1.729912
# 16       0.342968      -0.196330             0.410864           -0.592358
#
#     uninsured_under_65  primary_care_physicians  dentists  \
# 0            -0.207188                -0.116308  1.264953
# 1             0.377328                 0.352843 -1.069037
# 2             0.503580                -0.197443 -0.569610
# 3            -0.495216                 0.441988  0.746227
# 4             0.870980                 0.318222  0.069740
# 5            -0.128087                -0.653996 -0.423034
# 6             0.164020                -0.702905 -0.639803
# 7            -0.438424                 0.410770  0.397118
# 8             2.131544                -1.151093 -0.782853
# 9            -0.361268                 0.120177  0.134707
# 10            2.294315                -1.033180 -0.426552
# 11           -0.163786                -0.002067 -0.451777
# 12           -1.421320                 0.689673  1.626408
# 13           -0.600164                 1.289020  3.444460
# 14           -0.054487                -0.118192 -0.856854
# 15            0.799931                -1.020308 -1.156585
# 16            0.795737                -0.088992 -0.685618
#
#     mental_health_providers  flu_vaccinations  unemployed  \
# 0                  2.317867         -0.365548    0.015911
# 1                  0.648601          0.692617    0.424981
# 2                 -0.413739         -0.153915   -0.219963
# 3                  0.388537          0.269351   -0.461550
# 4                 -0.730641          0.269351   -1.246190
# 5                 -0.395580          1.010067    0.432628
# 6                 -0.627066         -2.058612    1.461963
# 7                 -0.368373          0.057718    0.268198
# 8                  0.466701         -1.212080    1.043124
# 9                  0.627991          1.327516   -0.586380
# 10                 0.466701          0.057718   -0.171448
# 11                -0.504987          0.163535   -0.591735
# 12                 3.025099          0.269351   -0.117765
# 13                 1.294550          0.269351   -0.599018
# 14                -0.658985         -0.894631    0.116050
# 15                -0.469692          0.163535    1.474105
# 16                 0.435380         -1.317897    0.008438
#
#     diabetes_prevalence  hiv_prevalence  limited_access_to_healthy_foods  \
# 0              0.316245        0.925293                        -0.176053
# 1              0.847343       -0.070844                         0.692864
# 2             -0.002414       -0.093004                         1.077791
# 3             -0.533512        0.484735                         0.061637
# 4             -1.861257       -0.783653                        -0.533032
# 5              0.528684       -0.086673                         0.179339
# 6             -0.161743        0.232007                        -0.273260
# 7              0.050696        0.875170                         1.938087
# 8              2.015758       -0.499796                         2.763878
# 9             -2.020586       -0.534091                         0.713774
# 10             0.316245       -0.409046                        -0.073834
# 11             1.006672       -0.189558                        -0.526729
# 12             0.210025        0.662013                         0.145677
# 13            -0.321073        4.712516                         0.310942
# 14            -0.427292        0.468906                        -0.627982
# 15             0.634903        0.971723                         1.839263
# 16            -0.374183       -0.483967                        -0.396469
#
#     uninsured_children  other_primary_care_providers  median_household_income
# 0            -0.597911                      1.011982                -0.740788
# 1            -0.019996                     -0.770797                -0.354487
# 2             0.316586                     -0.451917                -1.131369
# 3            -0.426451                      0.498051                 0.474429
# 4             1.528704                      1.215025                 0.845909
# 5            -0.585454                     -0.206876                -0.367331
# 6             0.165334                     -0.521167                -1.241694
# 7            -0.074634                      0.323697                -0.555157
# 8             0.943967                     -1.122902                -0.795566
# 9             0.103235                     -0.214118                 0.012493
# 10            1.749206                     -0.310781                -0.355914
# 11            0.123946                     -0.969158                -0.097502
# 12           -1.206405                     -0.110443                 0.543807
# 13           -2.000221                      3.023537                 0.527231
# 14            1.184392                     -0.375797                -0.047554
# 15           -1.057197                      0.064926                -1.375840
# 16            0.422468                      0.306847                -0.325836

# %%
to_drop
# Out:
# ['uninsured_adults']

# %%
#Measure of the colinearity among predictor variables within the multiple regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
[variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
# Out:
# [4.445808400688181,
#  5.3290775093168,
#  2.2614631809310946,
#  5.137938173527606,
#  79.86508601370011,
#  3.151014180020215,
#  3.337601836334743,
#  1.9987224932788974,
#  2.052038719480654,
#  3.9197766352151215,
#  3.108041507103917,
#  1.885803928890591,
#  1.825437099881702,
#  66.60657162850089,
#  7.13379949687176,
#  1.8518982388562861,
#  7.61855120224561]

# %%
#Measure of the colinearity among predictor variables within the multiple regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
[variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
# Out:
# [4.445808400688181,
#  5.3290775093168,
#  2.2614631809310946,
#  5.137938173527606,
#  79.86508601370011,
#  3.151014180020215,
#  3.337601836334743,
#  1.9987224932788974,
#  2.052038719480654,
#  3.9197766352151215,
#  3.108041507103917,
#  1.885803928890591,
#  1.825437099881702,
#  66.60657162850089,
#  7.13379949687176,
#  1.8518982388562861,
#  7.61855120224561]

# %%
df_health_features.corrwith(target).abs()
# Out:
# adult_smoking                      0.433455
# adult_obesity                      0.451554
# physical_inactivity                0.447442
# excessive_drinking                 0.549621
# uninsured_under_65                 0.106498
# primary_care_physicians            0.161208
# dentists                           0.117744
# mental_health_providers            0.081624
# flu_vaccinations                   0.243868
# unemployed                         0.354333
# diabetes_prevalence                0.391140
# hiv_prevalence                     0.334391
# limited_access_to_healthy_foods    0.120908
# uninsured_adults                   0.239026
# uninsured_children                 0.255867
# other_primary_care_providers       0.096865
# median_household_income            0.581632
# dtype: float64

# %%
from sklearn.feature_selection import SelectKBest, f_regression,mutual_info_regression
X_train3, X_test3, y_train3, y_test3 = train_test_split(df_health_features, target, random_state=25,test_size=0.2)
selector = SelectKBest(f_regression, k=15)
selector.fit(X_train3, y_train3)
# Out:
# SelectKBest(k=15, score_func=<function f_regression at 0x7f7ee14cea70>)

# %%
selected_columns = X_train3.columns[selector.get_support()]
removed_columns = X_train3.columns[~selector.get_support()]
# X_train = X_train3[selected_columns]
# X_test = X_test3[selected_columns]

# %%
list(removed_columns)
# Out:
# ['dentists', 'mental_health_providers']

# %%
list(selected_columns)
# Out:
# ['adult_smoking',
#  'adult_obesity',
#  'physical_inactivity',
#  'excessive_drinking',
#  'uninsured_under_65',
#  'primary_care_physicians',
#  'flu_vaccinations',
#  'unemployed',
#  'diabetes_prevalence',
#  'hiv_prevalence',
#  'limited_access_to_healthy_foods',
#  'uninsured_adults',
#  'uninsured_children',
#  'other_primary_care_providers',
#  'median_household_income']

# %%
#instantiate a linear regression object
lm_kbest = LinearRegression()

#fit the linear regression to the data
lm_kbest = lm_kbest.fit(X_train3[selected_columns], y_train3)

y_train_kbest = lm_kbest.predict(X_train3[selected_columns])

train3_rmse = np.sqrt(metrics.mean_squared_error(y_train3, y_train_kbest))

print('Training Root Mean Squared Error:' , train3_rmse)

y_kbest = lm_kbest.predict(X_test3[selected_columns])

test3_rmse = np.sqrt(metrics.mean_squared_error(y_test3, y_kbest))

print('Testing Root Mean Squared Error:' , test3_rmse)
# Out:
# Training Root Mean Squared Error: 1.1037371516857302
# Testing Root Mean Squared Error: 1.1618283231281563

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(df_poly2, target, random_state=25,test_size=0.2)

# %%
from sklearn.feature_selection import RFECV

lm4 = linear_model.LinearRegression()

# %%
# Create recursive feature eliminator that scores features by mean squared errors
selector = RFECV(estimator=lm4, step=1, cv=10, scoring='neg_mean_squared_error')

# %%
# Fit recursive feature eliminator 
selector.fit(X_train4, y_train4)
# Out:
# RFECV(cv=10,
#       estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                  normalize=False),
#       min_features_to_select=1, n_jobs=None, scoring='neg_mean_squared_error',
#       step=1, verbose=0)

# %%
selected_rfe = X_train4.columns[selector.support_]
removed_rfe = X_train4.columns[~selector.support_]

# %%
list(removed_rfe)
# Out:
# ['adult_smoking',
#  'adult_obesity',
#  'physical_inactivity',
#  'excessive_drinking',
#  'uninsured_under_65',
#  'primary_care_physicians',
#  'dentists',
#  'mental_health_providers',
#  'flu_vaccinations',
#  'unemployed',
#  'diabetes_prevalence',
#  'hiv_prevalence',
#  'limited_access_to_healthy_foods',
#  'uninsured_adults',
#  'uninsured_children',
#  'other_primary_care_providers',
#  'median_household_income',
#  'adult_smoking^2',
#  'adult_smoking adult_obesity',
#  'adult_smoking physical_inactivity',
#  'adult_smoking excessive_drinking',
#  'adult_smoking uninsured_under_65',
#  'adult_smoking dentists',
#  'adult_smoking mental_health_providers',
#  'adult_smoking flu_vaccinations',
#  'adult_smoking unemployed',
#  'adult_smoking diabetes_prevalence',
#  'adult_smoking hiv_prevalence',
#  'adult_smoking limited_access_to_healthy_foods',
#  'adult_smoking uninsured_adults',
#  'adult_smoking uninsured_children',
#  'adult_smoking other_primary_care_providers',
#  'adult_smoking median_household_income',
#  'adult_obesity^2',
#  'adult_obesity physical_inactivity',
#  'adult_obesity excessive_drinking',
#  'adult_obesity uninsured_under_65',
#  'adult_obesity primary_care_physicians',
#  'adult_obesity dentists',
#  'adult_obesity mental_health_providers',
#  'adult_obesity flu_vaccinations',
#  'adult_obesity unemployed',
#  'adult_obesity diabetes_prevalence',
#  'adult_obesity hiv_prevalence',
#  'adult_obesity limited_access_to_healthy_foods',
#  'adult_obesity uninsured_adults',
#  'adult_obesity uninsured_children',
#  'adult_obesity other_primary_care_providers',
#  'adult_obesity median_household_income',
#  'physical_inactivity^2',
#  'physical_inactivity excessive_drinking',
#  'physical_inactivity uninsured_under_65',
#  'physical_inactivity primary_care_physicians',
#  'physical_inactivity mental_health_providers',
#  'physical_inactivity flu_vaccinations',
#  'physical_inactivity unemployed',
#  'physical_inactivity diabetes_prevalence',
#  'physical_inactivity hiv_prevalence',
#  'physical_inactivity limited_access_to_healthy_foods',
#  'physical_inactivity uninsured_adults',
#  'physical_inactivity uninsured_children',
#  'physical_inactivity median_household_income',
#  'excessive_drinking^2',
#  'excessive_drinking uninsured_under_65',
#  'excessive_drinking dentists',
#  'excessive_drinking mental_health_providers',
#  'excessive_drinking flu_vaccinations',
#  'excessive_drinking unemployed',
#  'excessive_drinking diabetes_prevalence',
#  'excessive_drinking hiv_prevalence',
#  'excessive_drinking limited_access_to_healthy_foods',
#  'excessive_drinking uninsured_adults',
#  'excessive_drinking uninsured_children',
#  'excessive_drinking median_household_income',
#  'uninsured_under_65^2',
#  'uninsured_under_65 primary_care_physicians',
#  'uninsured_under_65 mental_health_providers',
#  'uninsured_under_65 flu_vaccinations',
#  'uninsured_under_65 unemployed',
#  'uninsured_under_65 diabetes_prevalence',
#  'uninsured_under_65 hiv_prevalence',
#  'uninsured_under_65 limited_access_to_healthy_foods',
#  'uninsured_under_65 uninsured_adults',
#  'uninsured_under_65 uninsured_children',
#  'uninsured_under_65 median_household_income',
#  'primary_care_physicians^2',
#  'primary_care_physicians dentists',
#  'primary_care_physicians mental_health_providers',
#  'primary_care_physicians flu_vaccinations',
#  'primary_care_physicians diabetes_prevalence',
#  'primary_care_physicians hiv_prevalence',
#  'primary_care_physicians limited_access_to_healthy_foods',
#  'primary_care_physicians uninsured_adults',
#  'primary_care_physicians uninsured_children',
#  'primary_care_physicians other_primary_care_providers',
#  'primary_care_physicians median_household_income',
#  'dentists^2',
#  'dentists mental_health_providers',
#  'dentists flu_vaccinations',
#  'dentists unemployed',
#  'dentists hiv_prevalence',
#  'dentists limited_access_to_healthy_foods',
#  'dentists uninsured_children',
#  'dentists other_primary_care_providers',
#  'dentists median_household_income',
#  'mental_health_providers^2',
#  'mental_health_providers flu_vaccinations',
#  'mental_health_providers unemployed',
#  'mental_health_providers diabetes_prevalence',
#  'mental_health_providers hiv_prevalence',
#  'mental_health_providers limited_access_to_healthy_foods',
#  'mental_health_providers uninsured_adults',
#  'mental_health_providers uninsured_children',
#  'mental_health_providers other_primary_care_providers',
#  'mental_health_providers median_household_income',
#  'flu_vaccinations^2',
#  'flu_vaccinations unemployed',
#  'flu_vaccinations diabetes_prevalence',
#  'flu_vaccinations hiv_prevalence',
#  'flu_vaccinations limited_access_to_healthy_foods',
#  'flu_vaccinations uninsured_adults',
#  'flu_vaccinations uninsured_children',
#  'flu_vaccinations other_primary_care_providers',
#  'flu_vaccinations median_household_income',
#  'unemployed^2',
#  'unemployed diabetes_prevalence',
#  'unemployed hiv_prevalence',
#  'unemployed limited_access_to_healthy_foods',
#  'unemployed uninsured_adults',
#  'unemployed uninsured_children',
#  'unemployed other_primary_care_providers',
#  'unemployed median_household_income',
#  'diabetes_prevalence^2',
#  'diabetes_prevalence hiv_prevalence',
#  'diabetes_prevalence limited_access_to_healthy_foods',
#  'diabetes_prevalence uninsured_adults',
#  'diabetes_prevalence uninsured_children',
#  'diabetes_prevalence median_household_income',
#  'hiv_prevalence^2',
#  'hiv_prevalence limited_access_to_healthy_foods',
#  'hiv_prevalence uninsured_adults',
#  'hiv_prevalence uninsured_children',
#  'hiv_prevalence other_primary_care_providers',
#  'hiv_prevalence median_household_income',
#  'limited_access_to_healthy_foods^2',
#  'limited_access_to_healthy_foods uninsured_adults',
#  'limited_access_to_healthy_foods uninsured_children',
#  'limited_access_to_healthy_foods other_primary_care_providers',
#  'limited_access_to_healthy_foods median_household_income',
#  'uninsured_adults^2',
#  'uninsured_adults uninsured_children',
#  'uninsured_adults median_household_income',
#  'uninsured_children^2',
#  'uninsured_children other_primary_care_providers',
#  'uninsured_children median_household_income',
#  'other_primary_care_providers^2',
#  'other_primary_care_providers median_household_income',
#  'median_household_income^2']

# %%
list(selected_rfe)
# Out:
# ['adult_smoking primary_care_physicians',
#  'physical_inactivity dentists',
#  'physical_inactivity other_primary_care_providers',
#  'excessive_drinking primary_care_physicians',
#  'excessive_drinking other_primary_care_providers',
#  'uninsured_under_65 dentists',
#  'uninsured_under_65 other_primary_care_providers',
#  'primary_care_physicians unemployed',
#  'dentists diabetes_prevalence',
#  'dentists uninsured_adults',
#  'diabetes_prevalence other_primary_care_providers',
#  'uninsured_adults other_primary_care_providers']

# %%
#instantiate a linear regression object
lm4_rfe = LinearRegression()

#fit the linear regression to the data
lm4_rfe = lm4_rfe.fit(X_train4[selected_rfe], y_train4)

y_rfe = lm4_rfe.predict(X_train4[selected_rfe])

train4_rmse = np.sqrt(metrics.mean_squared_error(y_train4, y_rfe))

print('Training Root Mean Squared Error:' , train4_rmse)

y_pred_rfe = lm4_rfe.predict(X_test4[selected_rfe])

test4_rmse = np.sqrt(metrics.mean_squared_error(y_test4, y_pred_rfe))

print('Testing Root Mean Squared Error:' , test4_rmse)
# Out:
# Training Root Mean Squared Error: 1.1061709661620298
# Testing Root Mean Squared Error: 1.7850496299413194

# %%
X_train5, X_test5, y_train5, y_test5 = train_test_split(df_poly2, target, random_state=25,test_size=0.2)

# %%
lm5_rfe = LinearRegression()
selected_rfe2 = X_train5.columns[selector.support_]
lm5_rfe = lm5_rfe.fit(X_train5[selected_rfe2], y_train5)

# %%
coef = pd.DataFrame(data=lm5_rfe.coef_ ).T
coef.columns = selected_rfe2

model_coef = coef.T.sort_values(by=0).T
model_coef.plot(kind='bar', title='Modal Coefficients', legend=True, figsize=(16,8),)

# %%
## training the model
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.01, normalize=False)

lasso.fit(X_train5,y_train5)

y_train_pred5 = lasso.predict(X_train5)
y_pred5 = lasso.predict(X_test5)

train5_rmse = metrics.mean_absolute_error(y_train5, y_train_pred5)
test5_rmse = np.sqrt(metrics.mean_squared_error(y_test5, y_pred5))
print('Training Error: '+ str(train5_rmse) )
print('Testing Error: '+ str(test5_rmse) )
# Out:
# Training Error: 0.7744669440373447
# Testing Error: 1.5568953277512967

# %%
lasso_coef01 = pd.DataFrame(data=lasso.coef_).T
lasso_coef01.columns = X_train5.columns
lasso_coef01 = lasso_coef01.T.sort_values(by=0).T
lasso_coef01.plot(kind='bar', title='Modal Coefficients', legend=True, figsize=(16,8))

# %%
## training the model
from sklearn.linear_model import Lasso

lasso1 = Lasso(alpha=.1, normalize=False)

lasso1.fit(X_train5,y_train5)

y_train_lasso1 = lasso1.predict(X_train5)
y_pred_lasso1 = lasso1.predict(X_test5)

train5_rmse_lasso1 = metrics.mean_absolute_error(y_train5, y_train_lasso1)
test5_rmse_lasso1 = np.sqrt(metrics.mean_squared_error(y_test5, y_pred_lasso1))
print('Training Error: '+ str(train5_rmse_lasso1) )
print('Testing Error: '+ str(test5_rmse_lasso1) )
# Out:
# Training Error: 0.837955076053498
# Testing Error: 1.5147285969208064

# %% [markdown]
# # Results

# %%
# Test Results
print('#1 Original Training Error: ', train_rmse, '#1 Original Testing Error: ', test_rmse)
print('#2 Poly Training Error: ', train2_rmse, '#2 Poly Testing Error: ', test2_rmse)
print('#3 F-Test Training Error: ', train3_rmse, '#3 F-Test Testing Error: ', test3_rmse)
print('#4 Recursive Training Error: ', train4_rmse, '#4 Recursive Testing Error: ', test4_rmse)
print('#5 Lasso Training Error: ', train5_rmse_lasso1, '#5 Lasso Testing Error: ', test5_rmse_lasso1)
# Out:
# #1 Original Training Error:  1.0862495100295781 #1 Original Testing Error:  1.1572966653109409
# #2 Poly Training Error:  2.4737922779493408e-14 #2 Poly Testing Error:  1.9080889957538718
# #3 F-Test Training Error:  1.1037371516857302 #3 F-Test Testing Error:  1.1618283231281563
# #4 Recursive Training Error:  1.1061709661620298 #4 Recursive Testing Error:  1.7850496299413194
# #5 Lasso Training Error:  0.837955076053498 #5 Lasso Testing Error:  1.5147285969208064

# %%
#Standardized RMSE to see error relative to the data 
print('Root Mean Squared Error Z-score:' , test3_rmse/target.std())
# Out:
# Root Mean Squared Error Z-score: 0.6135569413360117
