# %%
#Sample Variance
np.var()
def sample_variance(sample_men):
    sample_mean = np.mean(sample_men)
    return np.sum((sample_men - sample_mean) **2)/ (len(sample_men) -1)
​
# Pooled Variance T-test
def pooled_variance(s_men, s_women):
    n_1, n_2 = len(s_men), len(s_women)
    var_1, var_2 = sample_variance(s_men), sample_variance(s_women)
    return ((n_1-1) * var_1 + (n_2-1)* var_2)/((n_1 + n_2)-2)
​
# find the Z-score
stats.norm.ppf()
​
#find the P-value
stats.norm.cdf()
​
#find the T-score
stats.t.ppf(.05, df)
#uppertail is 1-/.05
​
#find the P-value
stats.t.cdf(.05, df)
​
#Two_tail T-value
stats.ttest_ind(store1, store2)
​
#Confidence Interval Z-score
def confidence_zscore(pop_mean, sigma, alpha1):
    return stats.norm.interval(alpha = alpha1, loc = pop_mean, scale = sigma)
​
#Confidence Interval T-score
def confidence_zscore(pop_mean, sigma, alpha1, dof):
    return stats.t.interval(alpha = alpha1, loc = pop_mean, df = dof, scale = sigma)

​
#Confidence Interval T-score was round to 4 decimal places
import numpy as np
import scipy.stats


def confidence(data, confidence):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2, n-1)
    return [round(m-h,4), round(m+h,4)]
​
#Confidence Interval T-score was round to 4 decimal places (Dan's answer)
from scipy import stats
from scipy.stats import sem, t
def confidence(sam, p):
    n= len(sam)
    est= sum(sam)/len(sam)
    std_err= sem(sam)
    m_o_e= std_err* t.ppf((1+p)/2, n-1)
    return [round(est-m_o_e, 4), round(est+ m_o_e, 4)]
​
#sample is the specific column, can be replaced with the number of observations and delete the len()
# One Tail one sample lower tail: T-score
def lower_one_sample_ttest(sample, xbar, pop_mean, sigma1, alpha1):
    mu = pop_mean
    x_bar = xbar
    sigma = sigma1
    alpha = alpha1
    df = len(sample) - 1
    t_crit = stats.t.ppf(alpha, df=df)
    results = stats.ttest_1samp(a= sample, popmean= mu)
    if results[0] > t_crit:
        print ("With the current information, we fail to reject the Null hypothesis with t-stat =",
                round(results[0], 2), ",  critical t-value =",  t_crit, "and p-value =", np.round((results[1]), 10))
    else:
        print ("We reject the Null hypothesis. Results are statistically significant with t-stat =",
                round(results[0], 2), "critical t-value",  t_crit, "and p-value =", np.round((results[1]), 10))
#One Tail one sample upper tail: T-score
def upper_one_sample_ttest(sample, xbar, pop_mean, sigma1, alpha1):
    mu = pop_mean
    x_bar = xbar
    sigma = sigma1
    alpha = alpha1
    df = len(sample) - 1
    t_crit = stats.t.ppf(1-alpha, df=df)
    results = stats.ttest_1samp(a= sample, popmean= mu)
    if results[0] >t_crit:
        print ("With the current information, we fail to reject the Null hypothesis with t-stat =",
                round(results[0], 2), ",  critical t-value =", t_crit, "and p-value =", np.round((results[1]), 10))
    else:
        print ("We reject the Null hypothesis. Results are statistically significant with t-stat =",
                round(results[0], 2), "between critical t-values ", t_crit, "and p-value =", np.round((results[1]), 10))
​
#Two tail one sample: T-score
def two_tail_one_sample_ttest(sample, xbar, pop_mean, sigma1, alpha1):
    mu = pop_mean
    x_bar = xbar
    sigma = sigma1
    alpha = alpha1 /2
    df = len(sample) - 1
    t_crit = stats.t.ppf(1-alpha, df=df)
    t_crit2 = (-1* t_crit)
    results = stats.ttest_1samp(a= sample, popmean= mu)
    if t_crit2 < results[0] <t_crit:
        print ("With the current information, we fail to reject the Null hypothesis with t-stat =",
                round(results[0], 2), ", between critical t-values =", t_crit2, ' &', t_crit, "and p-value =", np.round((results[1]), 10))
    else:
        print ("We reject the Null hypothesis. Results are statistically significant with t-stat =",
                round(results[0], 2), "not falling between critical t-values =", t_crit2, ' &', t_crit, "and p-value =", np.round((results[1]), 10))
​
#sample = number of obsevations
# One tail one sample lower tail: Z-score
def lower_one_sample_ztest(sample, xbar, pop_mean, sigma1, alpha1):
    mu = pop_mean
    x_bar = xbar
    sigma = sigma1
    alpha = alpha1
    df = (sample) - 1
    z_crit = stats.norm.ppf(alpha)
    results = (xbar- pop_mean)/(sigma1/np.sqrt((sample)))
    if results >z_crit:
        print ("With the current information, we fail to reject the Null hypothesis with z-stat =",
                round(results, 2), ", critical z-value =", z_crit)
    else:
        print ("We reject the Null hypothesis. Results are statistically significant with z-stat =",
                round(results, 2), " critical z-value =", z_crit)
​
​
#One tail one sample upper tail: Z-score
def upper_one_sample_ztest(sample, xbar, pop_mean, sigma1, alpha1):
    mu = pop_mean
    x_bar = xbar
    sigma = sigma1
    alpha = alpha1
    df = (sample) - 1
    z_crit = stats.norm.ppf(1-alpha)
    results = (xbar- pop_mean)/(sigma1/np.sqrt((sample)))
    if results <z_crit:
        print ("With the current information, we fail to reject the Null hypothesis with z-stat =",
                round(results, 2), ", critical z-value = ", z_crit)
    else:
        print ("We reject the Null hypothesis. Results are statistically significant with z-stat =",
                round(results, 2), " critical z-value =", z_crit)
​
#Two tail one sample: Z-score
def two_tail_one_sample_ztest(sample, xbar, pop_mean, sigma1, alpha1):
    mu = pop_mean
    x_bar = xbar
    sigma = sigma1
    alpha = alpha1 /2
    df = sample - 1
    z_crit = stats.norm.ppf(1-alpha)
    z_crit2 = (-1* z_crit)
    results = (xbar- pop_mean)/(sigma1/np.sqrt(sample))
    if z_crit2 < results <z_crit:
        print ("With the current information, we fail to reject the Null hypothesis with z-stat =",
                round(results, 2), ", between critical z-values ", z_crit2, ' &', z_crit)
    else:
        print ("We reject the Null hypothesis. Results are statistically significant with z-stat =",
                round(results, 2), "not falling between critical z-values ", z_crit2, ' &', z_crit)
​
​
​
#One tail two sample lower tail:  Z-score
​
#One tail two sample upper tail: Z-score
​
#Two tail two sample upper tail: Z-score
​
​
#One tail two sample lower tail:  T-score
def twosample_tstatistic(expr, ctrl):
    exp_mean, ctrl_mean = np.mean(expr), np.mean(ctrl)
    pool_var = pooled_variance(expr, ctrl)
    n_e, n_c = len(expr), len(ctrl)
    num = exp_mean - ctrl_mean
    denom = np.sqrt(pool_var * ((1/n_e)+(1/n_c)))
    return num / denom
​
#One tail two sample upper tail: T-score
​
#Two tail two sample upper tail: T-score
​
​
#Bayes Theorem
def bayes(P_a, P_b, P_b_given_a):
    P_a_given_b = (P_b_given_a * P_a)/P_b
    return P_a_given_b
​
​
#Math Factorial
import math
math.factorial(20)
